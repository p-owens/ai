# %% [markdown]
# PPO training model on breakout

# %%
# !pip install gym -q
# !pip install torch -q
# !pip install numpy -q
# !pip install matplotlib -q

# %% [markdown]
# Remember to mount your drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import random
import cv2
import numpy as np
import gym
from gym import Wrapper

from numpy import random

class CustomBreakout(Wrapper):
    def __init__(self, env, size=84, skip=4):
        super(CustomBreakout, self).__init__(env)
        self.skip = skip
        self.size = size
    
    def ProcessFrame(self, frame):
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (self.size, self.size)) / 255.0
        frame = np.expand_dims(frame, axis=0)
        return frame
    
    def step(self, action):
        total_reward = 0
        for _ in range(self.skip):
            state, reward, done, info = self.env.step(action)
            total_reward += reward
            
            if done:
                break
        state = self.ProcessFrame(state)
        return state, total_reward, done, info

    def reset(self):
        state = self.env.reset()
        state = self.ProcessFrame(state)
        return state
    
class CustomBreakout_stack(Wrapper):
    def __init__(self, env, size=84, skip=4):
        super(CustomBreakout_stack, self).__init__(env)
        self.skip = skip
        self.size = size
        self.history = []

    def ProcessFrame(self, frame):
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (self.size, self.size)) / 255.0
        return frame
    
    def step(self, action):
        total_reward = 0
        for _ in range(self.skip):
            state, reward, done, info = self.env.step(action)
            total_reward += reward
            
            if done==True:
                break

        state = self.ProcessFrame(state)

        self.history.append(state)
        del self.history[0]

        return np.stack(self.history), total_reward, done, info

    def reset(self):
        state = self.env.reset()
        state = self.ProcessFrame(state)
        self.history = [state, state, state, state]
        return np.stack(self.history)

def CreateBreakout(stack=True):
    env = gym.make('SpaceInvaders-v0')
    if stack:
        env = CustomBreakout_stack(env)
    else:
        env = CustomBreakout(env)
    return env

class MultipleBreakout:
    def __init__(self, N, stack=True):
        self.envs = [CreateBreakout(stack) for _ in range(N)]
    
    def reset(self):
        obs = []
        for env in self.envs:
            ob = env.reset()
            obs.append(ob)
        return np.stack(obs)
    
    def step(self, actions):
        obs, rewards, dones, infos = [], [], [], []
        for env, action in zip(self.envs, actions):
            ob, reward, done, info = env.step(action)
            if done:
                ob = env.reset()
            obs.append(ob)
            rewards.append(reward)
            dones.append(done)
            infos.append(info)
        return np.stack(obs), np.stack(rewards), np.stack(dones), info
    
    def render(self):
        for env in self.envs:
            env.render()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
from torch.distributions import Categorical

import numpy as np

class QNet(nn.Module):
    def __init__(self):
        super(QNet, self).__init__()

        # layers
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)

        self.ConvOutSize = self.get_conv_out_size()

        self.fc = nn.Linear(self.ConvOutSize * self.ConvOutSize * 64, 512)

        self.Q = nn.Linear(512, 4)

        self.initialize_weights()
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.view(-1, self.ConvOutSize * self.ConvOutSize * 64)

        x = F.relu(self.fc(x))
        q = self.Q(x)
        return q
    
    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)

    def get_conv_out_size(self):
        test_tensor = torch.FloatTensor(1, 4, 84, 84)
        out_tensor = self.conv3(self.conv2(self.conv1(test_tensor)))
        conv_out_size = out_tensor.size()[-1]
        return conv_out_size

class QNet_LSTM(nn.Module):
    def __init__(self):
        super(QNet_LSTM, self).__init__()

        # layers
        self.conv1 = nn.Conv2d(1, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)

        self.ConvOutSize = self.get_conv_out_size()

        self.lstm = nn.LSTMCell(self.ConvOutSize * self.ConvOutSize * 64, 512)

        self.Q = nn.Linear(512, 4)

        self.initialize_weights()
    
    def forward(self, x, hidden):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.view(-1, self.ConvOutSize * self.ConvOutSize * 64)

        h, c = self.lstm(x, hidden)

        q = self.Q(h)

        return q, (h, c)
    
    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.LSTMCell):
                nn.init.constant_(module.bias_ih, 0)
                nn.init.constant_(module.bias_hh, 0)

    def get_conv_out_size(self):
        test_tensor = torch.FloatTensor(1, 1, 84, 84)
        out_tensor = self.conv3(self.conv2(self.conv1(test_tensor)))
        conv_out_size = out_tensor.size()[-1]
        return conv_out_size

class ActorCriticNet(nn.Module):
    def __init__(self):
        super(ActorCriticNet, self).__init__()

        # layers
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)

        self.ConvOutSize = self.get_conv_out_size()

        self.fc = nn.Linear(self.ConvOutSize * self.ConvOutSize * 64, 512)

        self.Pi = nn.Linear(512, 4)
        self.V = nn.Linear(512, 1)

        self.initialize_weights()
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.view(-1, self.ConvOutSize * self.ConvOutSize * 64)

        x = F.relu(self.fc(x))

        prob = self.Pi(x)
        prob = F.softmax(prob, dim=-1)

        value = self.V(x)

        return prob, value
    
    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)

    def get_conv_out_size(self):
        test_tensor = torch.FloatTensor(1, 4, 84, 84)
        out_tensor = self.conv3(self.conv2(self.conv1(test_tensor)))
        conv_out_size = out_tensor.size()[-1]
        return conv_out_size

class ActorCriticNet_LSTM(nn.Module):
    def __init__(self):
        super(ActorCriticNet_LSTM, self).__init__()

        # layers
        self.conv1 = nn.Conv2d(1, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)

        self.ConvOutSize = self.get_conv_out_size()

        self.lstm = nn.LSTMCell(self.ConvOutSize * self.ConvOutSize * 64, 512)

        self.Pi = nn.Linear(512, 4)
        self.V = nn.Linear(512, 1)

        self.initialize_weights()
    
    def forward(self, x, hidden):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.view(-1, self.ConvOutSize * self.ConvOutSize * 64)

        h, c = self.lstm(x, hidden)

        prob = self.Pi(h)
        prob = F.softmax(prob, dim=-1)

        value = self.V(h)

        return prob, value, (h, c)
    
    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.LSTMCell):
                nn.init.constant_(module.bias_ih, 0)
                nn.init.constant_(module.bias_hh, 0)

    def get_conv_out_size(self):
        test_tensor = torch.FloatTensor(1, 1, 84, 84)
        out_tensor = self.conv3(self.conv2(self.conv1(test_tensor)))
        conv_out_size = out_tensor.size()[-1]
        return conv_out_size

# %%
#setting up the csv writer for logging
import csv
filename = './drive/MyDrive/ai_group/training_log_SpaceInvaders_rand.csv'

# %%
#required imports

import torch
import torch.nn as nn
import torch.nn.functional as F 
from torch.distributions import Categorical

import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

#required for timing games
import time

# %%
# settings
Train_max_step         = 4000000
learning_rate          = 1e-4
gamma                  = 0.99
lambd                  = 0.95
eps_clip               = 0.1
K_epoch                = 10
N_worker               = 1
T_horizon              = 16
save_interval          = 250
model_path             = './drive/MyDrive/ai_group/Models/SpaceInvaders_rand.model'
history_path           = './drive/MyDrive/ai_group/Train_Historys/SpaceInvaders_rand'

# %%
#setup training function

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

def train(Net, optimizer, states, actions, rewards, next_states, dones, old_probs):
    states = torch.FloatTensor(states).view(-1, 4, 84, 84).to(device) # (T*N, 4, 84, 84)
    actions = torch.LongTensor(actions).view(-1, 1).to(device) # (T*N, 1)
    rewards = torch.FloatTensor(rewards).view(-1, 1).to(device) # (T*N, 1)
    next_states = torch.FloatTensor(next_states).view(-1, 4, 84, 84).to(device) # (T*N, 4, 84, 84)
    dones = torch.FloatTensor(dones).view(-1, 1).to(device) # (T*N, 1)
    old_probs = torch.FloatTensor(old_probs).view(-1, 1).to(device) # (T*N, 1)

    for _ in range(K_epoch):
        probs, values = Net(states) # (T*N, num_action), (T*N, 1)
        _, next_values = Net(next_states) # (T*N, 1)

        td_targets = rewards + gamma * next_values * dones #(T*N, 1)
        deltas = td_targets - values # (T*N, 1)

        # calculate GAE
        deltas = deltas.view(T_horizon, N_worker, 1).cpu().detach().numpy() #(T, N, 1)
        masks = dones.view(T_horizon, N_worker, 1).cpu().numpy()
        advantages = []
        advantage = 0
        for delta, mask in zip(deltas[::-1], masks[::-1]):
            advantage = gamma * lambd * advantage * mask + delta
            advantages.append(advantage)
        advantages.reverse()
        advantages = torch.FloatTensor(advantages).view(-1, 1).to(device) # (T*N, 1)

        probs_a = probs.gather(1, actions) #(T*N, 1)

        m = Categorical(probs)
        entropy = m.entropy()

        ratio = torch.exp(torch.log(probs_a) - torch.log(old_probs))
        surr1 = ratio * advantages
        surr2 = torch.clamp(ratio, 1-eps_clip, 1+eps_clip) * advantages

        actor_loss = -torch.mean(torch.min(surr1, surr2))
        critic_loss = F.smooth_l1_loss(values, td_targets.detach())
        entropy_loss = torch.mean(entropy)

        loss = actor_loss + critic_loss - 0.01 * entropy_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# cuda

# %% [markdown]
# Rember to uncomment the lines in the follwing block if you want to load a previous model state!!!

# %%
#define main training loop

def main():
    env = MultipleBreakout(N_worker)
    Net = ActorCriticNet().to(device)

    """
    Uncomment this line to load a previous model
    """
    #Net.load_state_dict(torch.load(model_path))                  #Uncomment this line to load a previous model

    optimizer = torch.optim.Adam(Net.parameters(), learning_rate)

    scores = [0.0 for _ in range(N_worker)]
    score_history = []
    train_history = []
    reward_sum = []

    """
    Uncomment the next line if you want to load the previous model
    """  
    #train_history = np.load(history_path+'.npy').tolist()        #Uncomment this line to load a previous model
    
    step = 0

    state = env.reset() # (N, 4, 84, 84)

    print("Train Start")
    start_time = time.perf_counter()

    while step <= Train_max_step:
        states, actions, rewards, next_states, dones, old_probs = list(), list(), list(), list(), list(), list()
        for _ in range(T_horizon):
            prob, _ = Net(torch.FloatTensor(state).to(device))
            m = Categorical(prob)

            action = m.sample() # (N,)
            old_prob = prob.gather(1, action.unsqueeze(1)) # (N, 1)

            #action = action.cpu().detach().numpy()
            action = np.array([random.randint(4)])
            old_prob = old_prob.cpu().detach().numpy()

            next_state, reward, done, info = env.step(action)
            #print(action)
            lives = info['ale.lives']
            reward_sum.append(reward)
            
            if lives == 0:
              end_time = time.perf_counter()
              dur = end_time - start_time
              start_time = end_time
              with open(filename, mode='a') as csv_file:
                csv_writer = csv.writer(csv_file, delimiter=',')
                csv_writer.writerow([step, int(sum(reward_sum)[0]), dur])
              dur_s = "{:.3f} s".format(dur)
              print("Step : {0:7} | Reward : {1:4} | Duration :".format(step, int(sum(reward_sum)[0])), 
                    dur_s.rjust(9,' '))
              reward_sum.clear()
              
 
            # save transition
            states.append(state) # (T, N, 4, 84, 84)
            actions.append(action) # (T, N)
            rewards.append(reward/10.0) # (T, N)
            next_states.append(next_state) # (T, N, 4, 84, 84)
            dones.append(1-done) # (T, N)
            old_probs.append(old_prob)# (T, N, 1)


            # record score and check done
            for i, (r, d) in enumerate(zip(reward, done)):
                scores[i] += r

                if d==True:
                    score_history.append(scores[i])
                    scores[i] = 0.0
                    if len(score_history) > 250:
                        del score_history[0]

            state = next_state

            step += 1

            if step % save_interval == 0:
                torch.save(Net.state_dict(), model_path)
                train_history.append(mean(score_history))
                np.save(history_path, np.array(train_history))
                 # print("step : {}, Average score of last 250 episode : {:.1f}".format(step, mean(score_history)))

        train(Net, optimizer, states, actions, rewards, next_states, dones, old_probs)

    torch.save(Net.state_dict(), model_path)
    np.save(history_path, np.array(train_history))
     # print("Train end, avg_score of last 100 episode : {}".format(mean(score_history)))

# %%
if __name__ == "__main__":
    main()
# Out:
# Train Start
# Step :     160 | Reward :   60 | Duration :   3.383 s
# Step :     286 | Reward :   35 | Duration :   5.091 s
# Step :     425 | Reward :   15 | Duration :   2.769 s
# Step :     664 | Reward :  120 | Duration :   4.697 s
# Step :     802 | Reward :   70 | Duration :   2.805 s
# Step :    1006 | Reward :  125 | Duration :   3.833 s
# Step :    1160 | Reward :   25 | Duration :   3.094 s
# Step :    1278 | Reward :   10 | Duration :   2.483 s
# Step :    1454 | Reward :   95 | Duration :   3.357 s
# Step :    1550 | Reward :   20 | Duration :   1.912 s
# Step :    1676 | Reward :   15 | Duration :   2.458 s
# Step :    1829 | Reward :   35 | Duration :   3.113 s
# Step :    2061 | Reward :  155 | Duration :   4.377 s
# Step :    2161 | Reward :   10 | Duration :   2.144 s
# Step :    2317 | Reward :   25 | Duration :   2.888 s
# Step :    2539 | Reward :   90 | Duration :   4.387 s
# Step :    2644 | Reward :   30 | Duration :   2.165 s
# Step :    2983 | Reward :  565 | Duration :   6.519 s
# Step :    3130 | Reward :   10 | Duration :   2.870 s
# Step :    3275 | Reward :   25 | Duration :   2.827 s
# Step :    3357 | Reward :    5 | Duration :   1.560 s
# Step :    3513 | Reward :   25 | Duration :   3.142 s
# Step :    3656 | Reward :   65 | Duration :   2.777 s
# Step :    3791 | Reward :   20 | Duration :   2.552 s
# Step :    3872 | Reward :   10 | Duration :   1.799 s
# Step :    4072 | Reward :  160 | Duration :   3.787 s
# Step :    4253 | Reward :  155 | Duration :   3.449 s
# Step :    4420 | Reward :  110 | Duration :   3.342 s
# Step :    4559 | Reward :   50 | Duration :   2.566 s
# Step :    4782 | Reward :   95 | Duration :   4.359 s
# Step :    4891 | Reward :   15 | Duration :   2.159 s
# Step :    4968 | Reward :   10 | Duration :   1.532 s
# Step :    5163 | Reward :  175 | Duration :   3.758 s
# Step :    5269 | Reward :    0 | Duration :   2.201 s
# Step :    5418 | Reward :   95 | Duration :   2.798 s
# Step :    5520 | Reward :   10 | Duration :   2.171 s
# Step :    5638 | Reward :   45 | Duration :   2.198 s
# Step :    5733 | Reward :    5 | Duration :   1.872 s
# Step :    5931 | Reward :  105 | Duration :   3.794 s
# Step :    6097 | Reward :   70 | Duration :   3.583 s
# Step :    6292 | Reward :  250 | Duration :   3.763 s
# Step :    6415 | Reward :   25 | Duration :   2.234 s
# Step :    6660 | Reward :  170 | Duration :   4.957 s
# Step :    6794 | Reward :   80 | Duration :   2.542 s
# Step :    6969 | Reward :   65 | Duration :   3.418 s
# Step :    7096 | Reward :   50 | Duration :   2.529 s
# Step :    7261 | Reward :   65 | Duration :   3.166 s
# Step :    7350 | Reward :   10 | Duration :   1.829 s
# Step :    7524 | Reward :  130 | Duration :   3.449 s
# Step :    7690 | Reward :   80 | Duration :   3.114 s
# Step :    7870 | Reward :   95 | Duration :   3.472 s
# Step :    8061 | Reward :  100 | Duration :   3.715 s
# Step :    8194 | Reward :    5 | Duration :   2.728 s
# Step :    8312 | Reward :   25 | Duration :   2.245 s
# Step :    8544 | Reward :  350 | Duration :   4.657 s
# Step :    8700 | Reward :   40 | Duration :   2.840 s
# Step :    8860 | Reward :   75 | Duration :   3.171 s
# Step :    8963 | Reward :   35 | Duration :   2.132 s
# Step :    9186 | Reward :  140 | Duration :   4.343 s
# Step :    9424 | Reward :  170 | Duration :   4.999 s
# Step :    9584 | Reward :   60 | Duration :   3.178 s
# Step :    9710 | Reward :   15 | Duration :   2.243 s
# Step :    9831 | Reward :    5 | Duration :   2.462 s
# Step :    9989 | Reward :  100 | Duration :   3.072 s
# Step :   10183 | Reward :  150 | Duration :   3.727 s
# Step :   10282 | Reward :   35 | Duration :   1.932 s
# Step :   10499 | Reward :  155 | Duration :   4.286 s
# Step :   10686 | Reward :   65 | Duration :   3.544 s
# Step :   10781 | Reward :   10 | Duration :   1.905 s
# Step :   10986 | Reward :   35 | Duration :   4.038 s
# Step :   11111 | Reward :   10 | Duration :   2.626 s
# Step :   11207 | Reward :    5 | Duration :   1.860 s
# Step :   11291 | Reward :   30 | Duration :   1.659 s
# Step :   11419 | Reward :   80 | Duration :   2.488 s
# Step :   11526 | Reward :   20 | Duration :   2.171 s
# Step :   11630 | Reward :   15 | Duration :   1.907 s
# Step :   11762 | Reward :  120 | Duration :   2.780 s
# Step :   11883 | Reward :   65 | Duration :   2.259 s
# Step :   12192 | Reward :  160 | Duration :   6.183 s
# Step :   12352 | Reward :  150 | Duration :   3.151 s
# Step :   12477 | Reward :   65 | Duration :   2.245 s
# Step :   12603 | Reward :   80 | Duration :   2.549 s
# Step :   12804 | Reward :  155 | Duration :   4.093 s
# Step :   12963 | Reward :   80 | Duration :   3.109 s
# Step :   13123 | Reward :  105 | Duration :   3.155 s
# Step :   13258 | Reward :   15 | Duration :   2.557 s
# Step :   13401 | Reward :   45 | Duration :   2.796 s
# Step :   13556 | Reward :   15 | Duration :   3.112 s
# Step :   13683 | Reward :   30 | Duration :   2.469 s
# Step :   13832 | Reward :   90 | Duration :   2.886 s
# Step :   13949 | Reward :   20 | Duration :   2.178 s
# Step :   14092 | Reward :   50 | Duration :   3.104 s
# Step :   14182 | Reward :   35 | Duration :   1.846 s
# Step :   14362 | Reward :  140 | Duration :   3.472 s
# Step :   14546 | Reward :  180 | Duration :   3.709 s
# Step :   14761 | Reward :  195 | Duration :   4.104 s
# Step :   14904 | Reward :   60 | Duration :   2.779 s
# Step :   15014 | Reward :   20 | Duration :   2.192 s
# Step :   15271 | Reward :  185 | Duration :   5.049 s
# Step :   15430 | Reward :  110 | Duration :   3.105 s
# Step :   15635 | Reward :   30 | Duration :   4.058 s
# Step :   15783 | Reward :   30 | Duration :   2.895 s
# Step :   16038 | Reward :  155 | Duration :   4.944 s
# Step :   16197 | Reward :  120 | Duration :   3.105 s
# Step :   16359 | Reward :   45 | Duration :   3.155 s
# Step :   16540 | Reward :  155 | Duration :   3.579 s
# Step :   16714 | Reward :   30 | Duration :   3.640 s
# Step :   16951 | Reward :   55 | Duration :   4.665 s
# Step :   17046 | Reward :   10 | Duration :   1.909 s
# Step :   17208 | Reward :  155 | Duration :   3.114 s
# Step :   17343 | Reward :   50 | Duration :   3.033 s
# Step :   17496 | Reward :   90 | Duration :   3.509 s
# Step :   17692 | Reward :   85 | Duration :   3.771 s
# Step :   17795 | Reward :   40 | Duration :   2.203 s
# Step :   17995 | Reward :   55 | Duration :   3.750 s
# Step :   18192 | Reward :  350 | Duration :   3.985 s
# Step :   18304 | Reward :   75 | Duration :   2.207 s
# Step :   18473 | Reward :   75 | Duration :   3.163 s
# Step :   18634 | Reward :   90 | Duration :   3.141 s
# Step :   18803 | Reward :   60 | Duration :   3.424 s
# Step :   18926 | Reward :   35 | Duration :   2.231 s
# Step :   19090 | Reward :   80 | Duration :   3.688 s
# Step :   19275 | Reward :   80 | Duration :   3.482 s
# Step :   19486 | Reward :  155 | Duration :   4.086 s
# Step :   19580 | Reward :    0 | Duration :   1.897 s
# Step :   19872 | Reward :  250 | Duration :   5.810 s
# Step :   20126 | Reward :   85 | Duration :   4.728 s
# Step :   20274 | Reward :  140 | Duration :   3.115 s
# Step :   20412 | Reward :   35 | Duration :   2.528 s
# Step :   20535 | Reward :   30 | Duration :   2.552 s
# Step :   20728 | Reward :  120 | Duration :   3.754 s
# Step :   20860 | Reward :    5 | Duration :   2.550 s
# Step :   21018 | Reward :   15 | Duration :   3.169 s
# Step :   21145 | Reward :   35 | Duration :   2.496 s
# Step :   21270 | Reward :    0 | Duration :   2.522 s
# Step :   21440 | Reward :   80 | Duration :   3.393 s
# Step :   21567 | Reward :   10 | Duration :   2.294 s
# Step :   21743 | Reward :   90 | Duration :   3.400 s
# Step :   21973 | Reward :  120 | Duration :   4.688 s
# Step :   22158 | Reward :  105 | Duration :   3.513 s
# Step :   22288 | Reward :    5 | Duration :   2.785 s
# Step :   22463 | Reward :   65 | Duration :   3.185 s
# Step :   22623 | Reward :   45 | Duration :   3.151 s
# Step :   22724 | Reward :   30 | Duration :   2.126 s
# Step :   22851 | Reward :   20 | Duration :   2.533 s
# Step :   22977 | Reward :   20 | Duration :   2.516 s
# Step :   23085 | Reward :   35 | Duration :   1.981 s
# Step :   23238 | Reward :   50 | Duration :   3.077 s
# Step :   23416 | Reward :   25 | Duration :   3.441 s
# Step :   23506 | Reward :   35 | Duration :   1.874 s
# Step :   23730 | Reward :  145 | Duration :   4.380 s
# Step :   23962 | Reward :  145 | Duration :   4.412 s
# Step :   24092 | Reward :   80 | Duration :   2.547 s
# Step :   24212 | Reward :   25 | Duration :   2.468 s
# Step :   24371 | Reward :  105 | Duration :   3.154 s
# Step :   24553 | Reward :   90 | Duration :   3.495 s
# Step :   24781 | Reward :  105 | Duration :   4.423 s
# Step :   25028 | Reward :  135 | Duration :   4.985 s
# Step :   25262 | Reward :  130 | Duration :   4.393 s
# Step :   25501 | Reward :  165 | Duration :   4.647 s
# Step :   25692 | Reward :   65 | Duration :   3.729 s
# Step :   25816 | Reward :   45 | Duration :   2.537 s
# Step :   26004 | Reward :  125 | Duration :   3.746 s
# Step :   26124 | Reward :   15 | Duration :   2.220 s
# Step :   26340 | Reward :   80 | Duration :   4.355 s
# Step :   26638 | Reward :  265 | Duration :   5.553 s
# Step :   26849 | Reward :   60 | Duration :   4.267 s
# Step :   27133 | Reward :  305 | Duration :   5.311 s
# Step :   27259 | Reward :   35 | Duration :   2.517 s
# Step :   27429 | Reward :  105 | Duration :   3.405 s
# Step :   27527 | Reward :   25 | Duration :   1.911 s
# Step :   27767 | Reward :   75 | Duration :   4.701 s
# Step :   27912 | Reward :   30 | Duration :   2.814 s
# Step :   28052 | Reward :   50 | Duration :   2.814 s
# Step :   28276 | Reward :   70 | Duration :   4.395 s
# Step :   28426 | Reward :   30 | Duration :   2.793 s
# Step :   28551 | Reward :   60 | Duration :   2.515 s
# Step :   28888 | Reward :  180 | Duration :   6.582 s
# Step :   29083 | Reward :   50 | Duration :   4.072 s
# Step :   29210 | Reward :   50 | Duration :   2.490 s
# Step :   29411 | Reward :  110 | Duration :   4.046 s
# Step :   29532 | Reward :   10 | Duration :   2.258 s
# Step :   29701 | Reward :   55 | Duration :   3.397 s
# Step :   29853 | Reward :   35 | Duration :   2.893 s
# Step :   30086 | Reward :  140 | Duration :   4.674 s
# Step :   30285 | Reward :  155 | Duration :   3.772 s
# Step :   30384 | Reward :   45 | Duration :   2.127 s
# Step :   30480 | Reward :   35 | Duration :   1.862 s
# Step :   30698 | Reward :  115 | Duration :   4.147 s
# Step :   30825 | Reward :   65 | Duration :   2.555 s
# Step :   31011 | Reward :   35 | Duration :   3.743 s
# Step :   31224 | Reward :   65 | Duration :   4.084 s
# Step :   31459 | Reward :  165 | Duration :   4.653 s
# Step :   31602 | Reward :   30 | Duration :   2.824 s
# Step :   31779 | Reward :   75 | Duration :   3.432 s
# Step :   31962 | Reward :   40 | Duration :   3.428 s
# Step :   32059 | Reward :   55 | Duration :   1.908 s
# Step :   32258 | Reward :  110 | Duration :   4.008 s
# Step :   32389 | Reward :   30 | Duration :   2.526 s
# Step :   32536 | Reward :   75 | Duration :   2.864 s
# Step :   32883 | Reward :  375 | Duration :   6.825 s
# Step :   33049 | Reward :  140 | Duration :   3.201 s
# Step :   33252 | Reward :   60 | Duration :   4.060 s
# Step :   33372 | Reward :   55 | Duration :   2.189 s
# Step :   33500 | Reward :   50 | Duration :   2.510 s
# Step :   33667 | Reward :  105 | Duration :   3.398 s
# Step :   33773 | Reward :   60 | Duration :   1.968 s
# Step :   33950 | Reward :   55 | Duration :   3.411 s
# Step :   34040 | Reward :   65 | Duration :   1.919 s
# Step :   34193 | Reward :   50 | Duration :   3.058 s
# Step :   34354 | Reward :   45 | Duration :   3.153 s
# Step :   34513 | Reward :   90 | Duration :   3.178 s
# Step :   34650 | Reward :   75 | Duration :   2.517 s
# Step :   34827 | Reward :   45 | Duration :   3.462 s
# Step :   34953 | Reward :   10 | Duration :   2.490 s
# Step :   35117 | Reward :   55 | Duration :   3.139 s
# Step :   35262 | Reward :   90 | Duration :   2.840 s
# Step :   35477 | Reward :  200 | Duration :   4.321 s
# Step :   35649 | Reward :   55 | Duration :   3.694 s
# Step :   35826 | Reward :  120 | Duration :   3.459 s
# Step :   35923 | Reward :   10 | Duration :   1.863 s
# Step :   36099 | Reward :   95 | Duration :   3.409 s
# Step :   36236 | Reward :  105 | Duration :   2.521 s
# Step :   36394 | Reward :   55 | Duration :   3.148 s
# Step :   36518 | Reward :   55 | Duration :   2.526 s
# Step :   36717 | Reward :  130 | Duration :   3.722 s
# Step :   36883 | Reward :  110 | Duration :   3.357 s
# Step :   37049 | Reward :   55 | Duration :   3.144 s
# Step :   37173 | Reward :   80 | Duration :   2.457 s
# Step :   37371 | Reward :  105 | Duration :   3.805 s
# Step :   37471 | Reward :   20 | Duration :   1.878 s
# Step :   37586 | Reward :   60 | Duration :   2.498 s
# Step :   37772 | Reward :   85 | Duration :   3.537 s
# Step :   37929 | Reward :   90 | Duration :   3.073 s
# Step :   38116 | Reward :   60 | Duration :   3.725 s
# Step :   38333 | Reward :   85 | Duration :   4.115 s
# Step :   38434 | Reward :   30 | Duration :   2.111 s
# Step :   38598 | Reward :  125 | Duration :   3.130 s
# Step :   38758 | Reward :  110 | Duration :   3.133 s
# Step :   38995 | Reward :  160 | Duration :   4.648 s
# Step :   39122 | Reward :   45 | Duration :   2.557 s
# Step :   39334 | Reward :  100 | Duration :   4.102 s
# Step :   39507 | Reward :   65 | Duration :   3.413 s
# Step :   39736 | Reward :  120 | Duration :   4.327 s
# Step :   39987 | Reward :  110 | Duration :   4.955 s
# Step :   40168 | Reward :  155 | Duration :   3.415 s
# Step :   40493 | Reward :  195 | Duration :   6.251 s
# Step :   40635 | Reward :    5 | Duration :   2.835 s
# Step :   40742 | Reward :   15 | Duration :   2.171 s
# Step :   40918 | Reward :   70 | Duration :   3.471 s
# Step :   41076 | Reward :   70 | Duration :   3.110 s
# Step :   41205 | Reward :   15 | Duration :   2.460 s
# Step :   41542 | Reward :  190 | Duration :   6.563 s
# Step :   41857 | Reward :  205 | Duration :   6.161 s
# Step :   42015 | Reward :   25 | Duration :   2.927 s
# Step :   42173 | Reward :   35 | Duration :   3.123 s
# Step :   42370 | Reward :   95 | Duration :   4.376 s
# Step :   42514 | Reward :   50 | Duration :   2.801 s
# Step :   42630 | Reward :   45 | Duration :   2.212 s
# Step :   42766 | Reward :   25 | Duration :   2.555 s
# Step :   43053 | Reward :  310 | Duration :   5.623 s
# Step :   43355 | Reward :  215 | Duration :   5.904 s
# Step :   43627 | Reward :  140 | Duration :   5.254 s
# Step :   43900 | Reward :  140 | Duration :   5.307 s
# Step :   43998 | Reward :   35 | Duration :   1.877 s
# Step :   44299 | Reward :  205 | Duration :   6.180 s
# Step :   44420 | Reward :   30 | Duration :   2.477 s
# Step :   44548 | Reward :   70 | Duration :   2.533 s
# Step :   44760 | Reward :  140 | Duration :   4.085 s
# Step :   44884 | Reward :   45 | Duration :   2.503 s
# Step :   45021 | Reward :   20 | Duration :   2.571 s
# Step :   45111 | Reward :   30 | Duration :   1.835 s
# Step :   45257 | Reward :   55 | Duration :   2.825 s
# Step :   45382 | Reward :   20 | Duration :   2.473 s
# Step :   45467 | Reward :   50 | Duration :   1.593 s
# Step :   45636 | Reward :   80 | Duration :   3.438 s
# Step :   45735 | Reward :   45 | Duration :   1.905 s
# Step :   46039 | Reward :  160 | Duration :   5.942 s
# Step :   46158 | Reward :   45 | Duration :   2.197 s
# Step :   46319 | Reward :   65 | Duration :   3.131 s
# Step :   46420 | Reward :   20 | Duration :   2.131 s
# Step :   46580 | Reward :   80 | Duration :   3.141 s
# Step :   46668 | Reward :   10 | Duration :   1.626 s
# Step :   46960 | Reward :  370 | Duration :   5.840 s
# Step :   47131 | Reward :   65 | Duration :   3.162 s
# Step :   47292 | Reward :   55 | Duration :   3.353 s
# Step :   47413 | Reward :   30 | Duration :   2.449 s
# Step :   47529 | Reward :    5 | Duration :   2.228 s
# Step :   47698 | Reward :   85 | Duration :   3.383 s
# Step :   47860 | Reward :   65 | Duration :   3.147 s
# Step :   47958 | Reward :   30 | Duration :   1.868 s
# Step :   48088 | Reward :   65 | Duration :   2.529 s
# Step :   48269 | Reward :  130 | Duration :   3.487 s
# Step :   48423 | Reward :   30 | Duration :   3.100 s
# Step :   48612 | Reward :  140 | Duration :   3.709 s
# Step :   48829 | Reward :  165 | Duration :   4.091 s
# Step :   49015 | Reward :  140 | Duration :   3.759 s
# Step :   49202 | Reward :  110 | Duration :   3.694 s
# Step :   49352 | Reward :   45 | Duration :   2.843 s
# Step :   49505 | Reward :   35 | Duration :   3.151 s
# Step :   49804 | Reward :  445 | Duration :   5.650 s
# Step :   49995 | Reward :   65 | Duration :   3.752 s
# Step :   50093 | Reward :   25 | Duration :   1.952 s
# Step :   50192 | Reward :   50 | Duration :   2.095 s
# Step :   50379 | Reward :  155 | Duration :   3.465 s
# Step :   50549 | Reward :   15 | Duration :   3.414 s
# Step :   50704 | Reward :   30 | Duration :   3.116 s
# Step :   50881 | Reward :  125 | Duration :   3.488 s
# Step :   51091 | Reward :  135 | Duration :   4.089 s
# Step :   51419 | Reward :  185 | Duration :   6.246 s
# Step :   51543 | Reward :  110 | Duration :   2.498 s
# Step :   51639 | Reward :   30 | Duration :   1.868 s
# Step :   51760 | Reward :   30 | Duration :   2.475 s
# Step :   52053 | Reward :  265 | Duration :   5.575 s
# Step :   52254 | Reward :  125 | Duration :   3.802 s
# Step :   52422 | Reward :   45 | Duration :   3.588 s
# Step :   52690 | Reward :  210 | Duration :   5.286 s
# Step :   52997 | Reward :  355 | Duration :   5.917 s
# Step :   53117 | Reward :   30 | Duration :   2.257 s
# Step :   53252 | Reward :   70 | Duration :   2.801 s
# Step :   53415 | Reward :   45 | Duration :   3.082 s
# Step :   53558 | Reward :   55 | Duration :   2.837 s
# Step :   53766 | Reward :  120 | Duration :   4.042 s
# Step :   53946 | Reward :  120 | Duration :   3.470 s
# Step :   54111 | Reward :  125 | Duration :   3.408 s
# Step :   54391 | Reward :  155 | Duration :   5.586 s
# Step :   54492 | Reward :    5 | Duration :   1.875 s
# Step :   54687 | Reward :   80 | Duration :   3.744 s
# Step :   54849 | Reward :  105 | Duration :   3.390 s
# Step :   55008 | Reward :   95 | Duration :   3.175 s
# Step :   55156 | Reward :   50 | Duration :   2.832 s
# Step :   55308 | Reward :   50 | Duration :   2.840 s
# Step :   55470 | Reward :  105 | Duration :   3.091 s
# Step :   55616 | Reward :   45 | Duration :   3.056 s
# Step :   55725 | Reward :   15 | Duration :   1.925 s
# Step :   55977 | Reward :  205 | Duration :   5.003 s
# Step :   56149 | Reward :  120 | Duration :   3.470 s
# Step :   56311 | Reward :   60 | Duration :   3.132 s
# Step :   56638 | Reward :  380 | Duration :   6.196 s
# Step :   56739 | Reward :   30 | Duration :   2.118 s
# Step :   56906 | Reward :   85 | Duration :   3.163 s
# Step :   57041 | Reward :   15 | Duration :   2.787 s
# Step :   57195 | Reward :   10 | Duration :   2.823 s
# Step :   57465 | Reward :  275 | Duration :   5.232 s
# Step :   57557 | Reward :   20 | Duration :   1.888 s
# Step :   57770 | Reward :  105 | Duration :   4.105 s
# Step :   57878 | Reward :   35 | Duration :   2.167 s
# Step :   58089 | Reward :  135 | Duration :   4.077 s
# Step :   58237 | Reward :   30 | Duration :   2.803 s
# Step :   58422 | Reward :  160 | Duration :   3.739 s
# Step :   58565 | Reward :   80 | Duration :   2.820 s
# Step :   58857 | Reward :  180 | Duration :   5.586 s
# Step :   59036 | Reward :   25 | Duration :   3.732 s
# Step :   59141 | Reward :   15 | Duration :   2.139 s
# Step :   59270 | Reward :   40 | Duration :   2.543 s
# Step :   59401 | Reward :   25 | Duration :   2.482 s
# Step :   59617 | Reward :   50 | Duration :   4.273 s
# Step :   59756 | Reward :   30 | Duration :   2.541 s
# Step :   59952 | Reward :  155 | Duration :   3.962 s
# Step :   60125 | Reward :  290 | Duration :   3.190 s
# Step :   60360 | Reward :  155 | Duration :   4.642 s
# Step :   60455 | Reward :   15 | Duration :   1.845 s
# Step :   60614 | Reward :   20 | Duration :   3.157 s
# Step :   60788 | Reward :   50 | Duration :   3.489 s
# Step :   60929 | Reward :   80 | Duration :   2.800 s
# Step :   61043 | Reward :    5 | Duration :   2.242 s
# Step :   61215 | Reward :   80 | Duration :   3.170 s
# Step :   61347 | Reward :   35 | Duration :   2.825 s
# Step :   61475 | Reward :   45 | Duration :   2.485 s
# Step :   61601 | Reward :   35 | Duration :   2.528 s
# Step :   61852 | Reward :  200 | Duration :   4.757 s
# Step :   61958 | Reward :   30 | Duration :   2.147 s
# Step :   62180 | Reward :  160 | Duration :   4.360 s
# Step :   62340 | Reward :   85 | Duration :   3.421 s
# Step :   62463 | Reward :    5 | Duration :   2.210 s
# Step :   62550 | Reward :   30 | Duration :   1.852 s
# Step :   62778 | Reward :   80 | Duration :   4.366 s
# Step :   62877 | Reward :   50 | Duration :   1.888 s
# Step :   63021 | Reward :   55 | Duration :   2.834 s
# Step :   63187 | Reward :   95 | Duration :   3.404 s
# Step :   63330 | Reward :   30 | Duration :   2.845 s
# Step :   63521 | Reward :   90 | Duration :   3.746 s
# Step :   63859 | Reward :  290 | Duration :   6.536 s
# Step :   64022 | Reward :  105 | Duration :   3.169 s
# Step :   64165 | Reward :   15 | Duration :   2.803 s
# Step :   64326 | Reward :    5 | Duration :   3.131 s
# Step :   64423 | Reward :    5 | Duration :   1.865 s
# Step :   64677 | Reward :  170 | Duration :   5.005 s
# Step :   64849 | Reward :  135 | Duration :   3.440 s
# Step :   65013 | Reward :  140 | Duration :   3.153 s
# Step :   65107 | Reward :   35 | Duration :   1.855 s
# Step :   65266 | Reward :  165 | Duration :   3.152 s
# Step :   65497 | Reward :  105 | Duration :   4.373 s
# Step :   65661 | Reward :   15 | Duration :   3.403 s
# Step :   65960 | Reward :  105 | Duration :   5.890 s
# Step :   66119 | Reward :   10 | Duration :   3.109 s
# Step :   66212 | Reward :   30 | Duration :   1.832 s
# Step :   66383 | Reward :  120 | Duration :   3.186 s
# Step :   66655 | Reward :  170 | Duration :   5.298 s
# Step :   66777 | Reward :   80 | Duration :   2.526 s
# Step :   66972 | Reward :  350 | Duration :   3.779 s
# Step :   67271 | Reward :   90 | Duration :   6.218 s
# Step :   67457 | Reward :  140 | Duration :   3.687 s
# Step :   67640 | Reward :   40 | Duration :   3.510 s
# Step :   67868 | Reward :  120 | Duration :   4.388 s
# Step :   67954 | Reward :    0 | Duration :   1.817 s
# Step :   68067 | Reward :   55 | Duration :   2.226 s
# Step :   68264 | Reward :   35 | Duration :   3.783 s
# Step :   68360 | Reward :   10 | Duration :   1.866 s
# Step :   68596 | Reward :  230 | Duration :   4.668 s
# Step :   68756 | Reward :   45 | Duration :   3.088 s
# Step :   68961 | Reward :  120 | Duration :   4.010 s
# Step :   69061 | Reward :    5 | Duration :   1.953 s
# Step :   69199 | Reward :   85 | Duration :   2.521 s
# Step :   69397 | Reward :  120 | Duration :   4.029 s
# Step :   69566 | Reward :   95 | Duration :   3.164 s
# Step :   69743 | Reward :  125 | Duration :   3.389 s
# Step :   69869 | Reward :   30 | Duration :   2.524 s
# Step :   70073 | Reward :   95 | Duration :   4.055 s
# Step :   70211 | Reward :    5 | Duration :   2.734 s
# Step :   70372 | Reward :   45 | Duration :   3.125 s
# Step :   70566 | Reward :  145 | Duration :   3.722 s
# Step :   70801 | Reward :  155 | Duration :   4.700 s
# Step :   70974 | Reward :   60 | Duration :   3.146 s
# Step :   71158 | Reward :  130 | Duration :   3.684 s
# Step :   71362 | Reward :   50 | Duration :   4.056 s
# Step :   71527 | Reward :   30 | Duration :   3.179 s
# Step :   71783 | Reward :  315 | Duration :   4.936 s
# Step :   71883 | Reward :   10 | Duration :   1.882 s
# Step :   71969 | Reward :   30 | Duration :   1.815 s
# Step :   72069 | Reward :   35 | Duration :   1.940 s
# Step :   72190 | Reward :   60 | Duration :   2.192 s
# Step :   72310 | Reward :   10 | Duration :   2.520 s
# Step :   72435 | Reward :   30 | Duration :   2.469 s
# Step :   72591 | Reward :  120 | Duration :   2.889 s
# Step :   72689 | Reward :   50 | Duration :   2.102 s
# Step :   72884 | Reward :  170 | Duration :   3.757 s
# Step :   72985 | Reward :   50 | Duration :   1.876 s
# Step :   73144 | Reward :   40 | Duration :   3.137 s
# Step :   73349 | Reward :  110 | Duration :   4.061 s
# Step :   73557 | Reward :  345 | Duration :   4.087 s
# Step :   73701 | Reward :   30 | Duration :   2.762 s
# Step :   73863 | Reward :   20 | Duration :   3.377 s
# Step :   73959 | Reward :    5 | Duration :   1.856 s
# Step :   74121 | Reward :    5 | Duration :   3.138 s
# Step :   74282 | Reward :   60 | Duration :   3.141 s
# Step :   74525 | Reward :  415 | Duration :   4.655 s
# Step :   74661 | Reward :   45 | Duration :   2.755 s
# Step :   74858 | Reward :  210 | Duration :   3.767 s
# Step :   75136 | Reward :  185 | Duration :   5.545 s
# Step :   75225 | Reward :   10 | Duration :   1.596 s
# Step :   75400 | Reward :   60 | Duration :   3.458 s
# Step :   75509 | Reward :   35 | Duration :   2.394 s
# Step :   75675 | Reward :   80 | Duration :   3.156 s
# Step :   75853 | Reward :   80 | Duration :   3.450 s
# Step :   76001 | Reward :   55 | Duration :   3.085 s
# Step :   76156 | Reward :   80 | Duration :   2.838 s
# Step :   76288 | Reward :   80 | Duration :   2.794 s
# Step :   76638 | Reward :  400 | Duration :   6.629 s
# Step :   76925 | Reward :  365 | Duration :   5.593 s
# Step :   77151 | Reward :  105 | Duration :   4.353 s
# Step :   77295 | Reward :   80 | Duration :   2.850 s
# Step :   77397 | Reward :    0 | Duration :   2.154 s
# Step :   77569 | Reward :   85 | Duration :   3.414 s
# Step :   77687 | Reward :   45 | Duration :   2.184 s
# Step :   77936 | Reward :  165 | Duration :   5.081 s
# Step :   78195 | Reward :  305 | Duration :   5.001 s
# Step :   78353 | Reward :  100 | Duration :   3.303 s
# Step :   78476 | Reward :   35 | Duration :   2.433 s
# Step :   78574 | Reward :   30 | Duration :   1.997 s
# Step :   78866 | Reward :  145 | Duration :   6.008 s
# Step :   79063 | Reward :   35 | Duration :   3.783 s
# Step :   79311 | Reward :  110 | Duration :   4.849 s
# Step :   79439 | Reward :   90 | Duration :   2.776 s
# Step :   79605 | Reward :   70 | Duration :   3.400 s
# Step :   79892 | Reward :  235 | Duration :   5.592 s
# Step :   80014 | Reward :   15 | Duration :   2.240 s
# Step :   80183 | Reward :   55 | Duration :   3.383 s
# Step :   80273 | Reward :    5 | Duration :   1.876 s
# Step :   80555 | Reward :  190 | Duration :   5.544 s
# Step :   80771 | Reward :  105 | Duration :   4.727 s
# Step :   80939 | Reward :  100 | Duration :   3.121 s
# Step :   81088 | Reward :   80 | Duration :   3.089 s
# Step :   81184 | Reward :    5 | Duration :   1.847 s
# Step :   81397 | Reward :  105 | Duration :   4.041 s
# Step :   81499 | Reward :   55 | Duration :   1.890 s
# Step :   81731 | Reward :   95 | Duration :   4.598 s
# Step :   81901 | Reward :  110 | Duration :   3.152 s
# Step :   82026 | Reward :   15 | Duration :   2.508 s
# Step :   82183 | Reward :   80 | Duration :   3.064 s
# Step :   82359 | Reward :  105 | Duration :   3.429 s
# Step :   82509 | Reward :   60 | Duration :   2.856 s
# Step :   82681 | Reward :   45 | Duration :   3.350 s
# Step :   82902 | Reward :  110 | Duration :   4.313 s
# Step :   83060 | Reward :  105 | Duration :   3.139 s
# Step :   83227 | Reward :   70 | Duration :   3.119 s
# Step :   83473 | Reward :  145 | Duration :   4.924 s
# Step :   83558 | Reward :    5 | Duration :   1.646 s
# Step :   83724 | Reward :   75 | Duration :   3.116 s
# Step :   83848 | Reward :   35 | Duration :   2.845 s
# Step :   84090 | Reward :  155 | Duration :   4.628 s
# Step :   84246 | Reward :   20 | Duration :   3.079 s
# Step :   84462 | Reward :   80 | Duration :   4.069 s
# Step :   84596 | Reward :   55 | Duration :   2.737 s
# Step :   84809 | Reward :   80 | Duration :   4.017 s
# Step :   85079 | Reward :  180 | Duration :   5.219 s
# Step :   85210 | Reward :   20 | Duration :   2.473 s
# Step :   85336 | Reward :    5 | Duration :   2.548 s
# Step :   85538 | Reward :  165 | Duration :   4.151 s
# Step :   85672 | Reward :   30 | Duration :   2.455 s
# Step :   85846 | Reward :   25 | Duration :   3.448 s
# Step :   85979 | Reward :   10 | Duration :   2.463 s
# Step :   86108 | Reward :   30 | Duration :   2.505 s
# Step :   86319 | Reward :   40 | Duration :   4.060 s
# Step :   86476 | Reward :   65 | Duration :   3.067 s
# Step :   86757 | Reward :  115 | Duration :   5.578 s
# Step :   86891 | Reward :   80 | Duration :   2.508 s
# Step :   87226 | Reward :  425 | Duration :   6.462 s
# Step :   87316 | Reward :    5 | Duration :   1.881 s
# Step :   87417 | Reward :   35 | Duration :   1.901 s
# Step :   87621 | Reward :  130 | Duration :   3.998 s
# Step :   87782 | Reward :  110 | Duration :   3.140 s
# Step :   88041 | Reward :  150 | Duration :   4.941 s
# Step :   88205 | Reward :  155 | Duration :   3.104 s
# Step :   88380 | Reward :   45 | Duration :   3.442 s
# Step :   88548 | Reward :   95 | Duration :   3.415 s
# Step :   88653 | Reward :   35 | Duration :   1.904 s
# Step :   88987 | Reward :  450 | Duration :   6.490 s
# Step :   89118 | Reward :   20 | Duration :   2.535 s
# Step :   89274 | Reward :   65 | Duration :   3.109 s
# Step :   89491 | Reward :  130 | Duration :   4.274 s
# Step :   89804 | Reward :  130 | Duration :   5.941 s
# Step :   89971 | Reward :   80 | Duration :   3.350 s
# Step :   90127 | Reward :   50 | Duration :   2.881 s
# Step :   90227 | Reward :   35 | Duration :   2.110 s
# Step :   90476 | Reward :  250 | Duration :   4.695 s
# Step :   90651 | Reward :  120 | Duration :   3.647 s
# Step :   90803 | Reward :   65 | Duration :   3.072 s
# Step :   90909 | Reward :   60 | Duration :   1.890 s
# Step :   91149 | Reward :  220 | Duration :   4.652 s
# Step :   91313 | Reward :  130 | Duration :   3.396 s
# Step :   91473 | Reward :   55 | Duration :   3.109 s
# Step :   91651 | Reward :   45 | Duration :   3.437 s
# Step :   91850 | Reward :   65 | Duration :   3.789 s
# Step :   92172 | Reward :  360 | Duration :   6.198 s
# Step :   92391 | Reward :  170 | Duration :   4.527 s
# Step :   92483 | Reward :   15 | Duration :   1.864 s
# Step :   92614 | Reward :   10 | Duration :   2.554 s
# Step :   92740 | Reward :   20 | Duration :   2.474 s
# Step :   92874 | Reward :    5 | Duration :   2.544 s
# Step :   93101 | Reward :  120 | Duration :   4.376 s
# Step :   93270 | Reward :   55 | Duration :   3.412 s
# Step :   93371 | Reward :   20 | Duration :   1.869 s
# Step :   93519 | Reward :   65 | Duration :   2.830 s
# Step :   93653 | Reward :   30 | Duration :   2.736 s
# Step :   93814 | Reward :   85 | Duration :   3.143 s
# Step :   94054 | Reward :   85 | Duration :   4.697 s
# Step :   94357 | Reward :  180 | Duration :   5.832 s
# Step :   94493 | Reward :   65 | Duration :   2.487 s
# Step :   94594 | Reward :   15 | Duration :   2.177 s
# Step :   94729 | Reward :   15 | Duration :   2.512 s
# Step :   94894 | Reward :   70 | Duration :   3.163 s
# Step :   95045 | Reward :   35 | Duration :   3.068 s
# Step :   95258 | Reward :  135 | Duration :   4.030 s
# Step :   95447 | Reward :  110 | Duration :   3.676 s
# Step :   95605 | Reward :   85 | Duration :   3.333 s
# Step :   95936 | Reward :  270 | Duration :   6.443 s
# Step :   96038 | Reward :   20 | Duration :   1.911 s
# Step :   96157 | Reward :   50 | Duration :   2.183 s
# Step :   96280 | Reward :   20 | Duration :   2.499 s
# Step :   96405 | Reward :    5 | Duration :   2.448 s
# Step :   96528 | Reward :    5 | Duration :   2.493 s
# Step :   96898 | Reward :  245 | Duration :   7.110 s
# Step :   97057 | Reward :   15 | Duration :   3.141 s
# Step :   97185 | Reward :   10 | Duration :   2.477 s
# Step :   97284 | Reward :   30 | Duration :   1.932 s
# Step :   97462 | Reward :  120 | Duration :   3.472 s
# Step :   97547 | Reward :   15 | Duration :   1.611 s
# Step :   97685 | Reward :   20 | Duration :   2.739 s
# Step :   97851 | Reward :   50 | Duration :   3.131 s
# Step :   98027 | Reward :  135 | Duration :   3.405 s
# Step :   98132 | Reward :   35 | Duration :   2.085 s
# Step :   98253 | Reward :   45 | Duration :   2.226 s
# Step :   98365 | Reward :    0 | Duration :   2.136 s
# Step :   98495 | Reward :   25 | Duration :   2.469 s
# Step :   98606 | Reward :   20 | Duration :   2.208 s
# Step :   98849 | Reward :  160 | Duration :   5.034 s
# Step :   99016 | Reward :   75 | Duration :   3.184 s
# Step :   99144 | Reward :   75 | Duration :   2.467 s
# Step :   99333 | Reward :   80 | Duration :   3.767 s
# Step :   99467 | Reward :   30 | Duration :   2.502 s
# Step :   99788 | Reward :  210 | Duration :   6.172 s
# Step :   99941 | Reward :   20 | Duration :   3.065 s
# Step :  100097 | Reward :   15 | Duration :   3.130 s
# Step :  100315 | Reward :  100 | Duration :   4.078 s
# Step :  100486 | Reward :   60 | Duration :   3.399 s
# Step :  100655 | Reward :  100 | Duration :   3.313 s
# Step :  100824 | Reward :   70 | Duration :   3.414 s
# Step :  100962 | Reward :   20 | Duration :   2.715 s
# Step :  101132 | Reward :   45 | Duration :   3.130 s
# Step :  101233 | Reward :   35 | Duration :   2.125 s
# Step :  101390 | Reward :  110 | Duration :   2.886 s
# Step :  101562 | Reward :   80 | Duration :   3.453 s
# Step :  101723 | Reward :  105 | Duration :   3.096 s
# Step :  101820 | Reward :   35 | Duration :   1.898 s
# Step :  101978 | Reward :   50 | Duration :   3.081 s
# Step :  102106 | Reward :   75 | Duration :   2.713 s
# Step :  102430 | Reward :  225 | Duration :   6.172 s
# Step :  102522 | Reward :   35 | Duration :   1.856 s
# Step :  102752 | Reward :  125 | Duration :   4.631 s
# Step :  102879 | Reward :    5 | Duration :   2.228 s
# Step :  103105 | Reward :  125 | Duration :   4.614 s
# Step :  103328 | Reward :   85 | Duration :   4.347 s
# Step :  103491 | Reward :   80 | Duration :   3.093 s
# Step :  103682 | Reward :   80 | Duration :   3.720 s
# Step :  103816 | Reward :   20 | Duration :   2.561 s
# Step :  104048 | Reward :  330 | Duration :   4.614 s
# Step :  104184 | Reward :   75 | Duration :   2.495 s
# Step :  104414 | Reward :   50 | Duration :   4.329 s
# Step :  104540 | Reward :   45 | Duration :   2.514 s
# Step :  104636 | Reward :   30 | Duration :   1.869 s
# Step :  104787 | Reward :  120 | Duration :   3.095 s
# Step :  104994 | Reward :  180 | Duration :   4.007 s
# Step :  105097 | Reward :   50 | Duration :   1.931 s
# Step :  105206 | Reward :   55 | Duration :   2.144 s
# Step :  105372 | Reward :  105 | Duration :   3.390 s
# Step :  105501 | Reward :    5 | Duration :   2.502 s
# Step :  105669 | Reward :  105 | Duration :   3.391 s
# Step :  105772 | Reward :    5 | Duration :   1.942 s
# Step :  105921 | Reward :   10 | Duration :   3.032 s
# Step :  106052 | Reward :   75 | Duration :   2.534 s
# Step :  106183 | Reward :   25 | Duration :   2.461 s
# Step :  106408 | Reward :  230 | Duration :   4.363 s
# Step :  106746 | Reward :  205 | Duration :   6.546 s
# Step :  106878 | Reward :   30 | Duration :   2.548 s
# Step :  107068 | Reward :  120 | Duration :   3.775 s
# Step :  107302 | Reward :  105 | Duration :   4.632 s
# Step :  107475 | Reward :  135 | Duration :   3.392 s
# Step :  107703 | Reward :  355 | Duration :   4.400 s
# Step :  107868 | Reward :   70 | Duration :   3.212 s
# Step :  108169 | Reward :  380 | Duration :   5.902 s
# Step :  108305 | Reward :   90 | Duration :   2.777 s
# Step :  108536 | Reward :   70 | Duration :   4.408 s
# Step :  108716 | Reward :   90 | Duration :   3.429 s
# Step :  108809 | Reward :   30 | Duration :   1.908 s
# Step :  108941 | Reward :   10 | Duration :   2.524 s
# Step :  109062 | Reward :   15 | Duration :   2.518 s
# Step :  109162 | Reward :    5 | Duration :   1.874 s
# Step :  109307 | Reward :   60 | Duration :   2.850 s
# Step :  109543 | Reward :  165 | Duration :   4.671 s
# Step :  109651 | Reward :   30 | Duration :   2.192 s
# Step :  109746 | Reward :   35 | Duration :   1.876 s
# Step :  110032 | Reward :  230 | Duration :   5.654 s
# Step :  110162 | Reward :   65 | Duration :   2.506 s
# Step :  110259 | Reward :   30 | Duration :   2.167 s
# Step :  110421 | Reward :   55 | Duration :   3.116 s
# Step :  110524 | Reward :   60 | Duration :   1.953 s
# Step :  110752 | Reward :  185 | Duration :   4.666 s
# Step :  110881 | Reward :   10 | Duration :   2.525 s
# Step :  111110 | Reward :  135 | Duration :   4.373 s
# Step :  111312 | Reward :  110 | Duration :   4.041 s
# Step :  111436 | Reward :   25 | Duration :   2.222 s
# Step :  111691 | Reward :  270 | Duration :   4.981 s
# Step :  111828 | Reward :   45 | Duration :   2.805 s
# Step :  111923 | Reward :    5 | Duration :   1.877 s
# Step :  112029 | Reward :   10 | Duration :   1.945 s
# Step :  112179 | Reward :   30 | Duration :   3.063 s
# Step :  112415 | Reward :  135 | Duration :   4.460 s
# Step :  112500 | Reward :   65 | Duration :   1.844 s
# Step :  112789 | Reward :  145 | Duration :   5.612 s
# Step :  113026 | Reward :  100 | Duration :   4.710 s
# Step :  113179 | Reward :   60 | Duration :   2.856 s
# Step :  113529 | Reward :  270 | Duration :   6.836 s
# Step :  113669 | Reward :   40 | Duration :   2.779 s
# Step :  113847 | Reward :   55 | Duration :   3.509 s
# Step :  114046 | Reward :  130 | Duration :   3.826 s
# Step :  114179 | Reward :  105 | Duration :   2.747 s
# Step :  114397 | Reward :  115 | Duration :   4.069 s
# Step :  114585 | Reward :  125 | Duration :   3.739 s
# Step :  114759 | Reward :   15 | Duration :   3.433 s
# Step :  114857 | Reward :   30 | Duration :   1.893 s
# Step :  114986 | Reward :   90 | Duration :   2.508 s
# Step :  115136 | Reward :   35 | Duration :   3.112 s
# Step :  115422 | Reward :   70 | Duration :   5.628 s
# Step :  115581 | Reward :   55 | Duration :   3.148 s
# Step :  115670 | Reward :   15 | Duration :   1.861 s
# Step :  115922 | Reward :  125 | Duration :   4.998 s
# Step :  116101 | Reward :   70 | Duration :   3.465 s
# Step :  116272 | Reward :   20 | Duration :   3.440 s
# Step :  116456 | Reward :   90 | Duration :   3.439 s
# Step :  116669 | Reward :  175 | Duration :   4.077 s
# Step :  116820 | Reward :  105 | Duration :   3.107 s
# Step :  116955 | Reward :   85 | Duration :   2.534 s
# Step :  117089 | Reward :   20 | Duration :   2.810 s
# Step :  117186 | Reward :   30 | Duration :   1.885 s
# Step :  117335 | Reward :    5 | Duration :   2.833 s
# Step :  117436 | Reward :   50 | Duration :   1.891 s
# Step :  117623 | Reward :  150 | Duration :   3.704 s
# Step :  117822 | Reward :  125 | Duration :   3.771 s
# Step :  118009 | Reward :  110 | Duration :   3.745 s
# Step :  118114 | Reward :   20 | Duration :   2.170 s
# Step :  118245 | Reward :   35 | Duration :   2.476 s
# Step :  118421 | Reward :   90 | Duration :   3.432 s
# Step :  118649 | Reward :  125 | Duration :   4.681 s
# Step :  118887 | Reward :  165 | Duration :   4.705 s
# Step :  119052 | Reward :   90 | Duration :   3.200 s
# Step :  119213 | Reward :   80 | Duration :   3.138 s
# Step :  119331 | Reward :   35 | Duration :   2.472 s
# Step :  119502 | Reward :   90 | Duration :   3.168 s
# Step :  119664 | Reward :   50 | Duration :   3.323 s
# Step :  119878 | Reward :   85 | Duration :   4.079 s
# Step :  120013 | Reward :   35 | Duration :   2.540 s
# Step :  120199 | Reward :  105 | Duration :   3.724 s
# Step :  120381 | Reward :   85 | Duration :   3.727 s
# Step :  120585 | Reward :   90 | Duration :   4.044 s
# Step :  120681 | Reward :   15 | Duration :   1.874 s
# Step :  120796 | Reward :  110 | Duration :   2.204 s
# Step :  121027 | Reward :  155 | Duration :   4.667 s
# Step :  121239 | Reward :   80 | Duration :   4.098 s
# Step :  121383 | Reward :   70 | Duration :   2.863 s
# Step :  121464 | Reward :    5 | Duration :   1.554 s
# Step :  121587 | Reward :   50 | Duration :   2.499 s
# Step :  121795 | Reward :   80 | Duration :   4.047 s
# Step :  121929 | Reward :   45 | Duration :   2.483 s
# Step :  122065 | Reward :   65 | Duration :   2.808 s
# Step :  122233 | Reward :  110 | Duration :   3.142 s
# Step :  122373 | Reward :  105 | Duration :   2.815 s
# Step :  122535 | Reward :   50 | Duration :   3.158 s
# Step :  122690 | Reward :   20 | Duration :   3.074 s
# Step :  122922 | Reward :  110 | Duration :   4.422 s
# Step :  123095 | Reward :   85 | Duration :   3.499 s
# Step :  123227 | Reward :    5 | Duration :   2.535 s
# Step :  123330 | Reward :   15 | Duration :   2.204 s
# Step :  123608 | Reward :  165 | Duration :   5.538 s
# Step :  123786 | Reward :  230 | Duration :   3.472 s
# Step :  123910 | Reward :   55 | Duration :   2.448 s
# Step :  124151 | Reward :  130 | Duration :   4.724 s
# Step :  124278 | Reward :   50 | Duration :   2.534 s
# Step :  124437 | Reward :   90 | Duration :   3.109 s
# Step :  124581 | Reward :   75 | Duration :   2.832 s
# Step :  124731 | Reward :   50 | Duration :   2.826 s
# Step :  124865 | Reward :   50 | Duration :   2.811 s
# Step :  125051 | Reward :   65 | Duration :   3.508 s
# Step :  125225 | Reward :   35 | Duration :   3.435 s
# Step :  125390 | Reward :   55 | Duration :   3.176 s
# Step :  125638 | Reward :  120 | Duration :   4.932 s
# Step :  125851 | Reward :  100 | Duration :   4.115 s
# Step :  126020 | Reward :  150 | Duration :   3.428 s
# Step :  126314 | Reward :  160 | Duration :   5.586 s
# Step :  126537 | Reward :  120 | Duration :   4.395 s
# Step :  126711 | Reward :   90 | Duration :   3.377 s
# Step :  126950 | Reward :  125 | Duration :   4.667 s
# Step :  127162 | Reward :   45 | Duration :   4.116 s
# Step :  127428 | Reward :  140 | Duration :   5.324 s
# Step :  127594 | Reward :  105 | Duration :   3.236 s
# Step :  127754 | Reward :   75 | Duration :   3.142 s
# Step :  127855 | Reward :   45 | Duration :   1.891 s
# Step :  128028 | Reward :   55 | Duration :   3.481 s
# Step :  128224 | Reward :   65 | Duration :   4.003 s
# Step :  128360 | Reward :   50 | Duration :   2.556 s
# Step :  128521 | Reward :   65 | Duration :   3.415 s
# Step :  128656 | Reward :   30 | Duration :   2.763 s
# Step :  128824 | Reward :   90 | Duration :   3.186 s
# Step :  128940 | Reward :   55 | Duration :   2.212 s
# Step :  129147 | Reward :  120 | Duration :   4.125 s
# Step :  129322 | Reward :   80 | Duration :   3.517 s
# Step :  129453 | Reward :   30 | Duration :   2.516 s
# Step :  129615 | Reward :   95 | Duration :   3.226 s
# Step :  129923 | Reward :  375 | Duration :   6.126 s
# Step :  130058 | Reward :   30 | Duration :   2.534 s
# Step :  130215 | Reward :   90 | Duration :   3.086 s
# Step :  130447 | Reward :  160 | Duration :   4.379 s
# Step :  130532 | Reward :   25 | Duration :   1.869 s
# Step :  130674 | Reward :   60 | Duration :   2.775 s
# Step :  130809 | Reward :   30 | Duration :   2.567 s
# Step :  131068 | Reward :  185 | Duration :   5.002 s
# Step :  131163 | Reward :   15 | Duration :   1.855 s
# Step :  131388 | Reward :  140 | Duration :   4.419 s
# Step :  131480 | Reward :    5 | Duration :   1.810 s
# Step :  131642 | Reward :  110 | Duration :   3.145 s
# Step :  131827 | Reward :  135 | Duration :   3.704 s
# Step :  131994 | Reward :  135 | Duration :   3.109 s
# Step :  132136 | Reward :   35 | Duration :   2.811 s
# Step :  132309 | Reward :   50 | Duration :   3.437 s
# Step :  132421 | Reward :   15 | Duration :   2.193 s
# Step :  132542 | Reward :   20 | Duration :   2.249 s
# Step :  132674 | Reward :   30 | Duration :   2.738 s
# Step :  132782 | Reward :   15 | Duration :   1.915 s
# Step :  132951 | Reward :   90 | Duration :   3.331 s
# Step :  133148 | Reward :  100 | Duration :   3.753 s
# Step :  133315 | Reward :   35 | Duration :   3.412 s
# Step :  133556 | Reward :  220 | Duration :   4.675 s
# Step :  133647 | Reward :    5 | Duration :   1.604 s
# Step :  133807 | Reward :   95 | Duration :   3.102 s
# Step :  133929 | Reward :    5 | Duration :   2.451 s
# Step :  134040 | Reward :   55 | Duration :   2.222 s
# Step :  134171 | Reward :   55 | Duration :   2.498 s
# Step :  134328 | Reward :   15 | Duration :   3.132 s
# Step :  134486 | Reward :  105 | Duration :   3.093 s
# Step :  134622 | Reward :   35 | Duration :   2.517 s
# Step :  134707 | Reward :   20 | Duration :   1.833 s
# Step :  134963 | Reward :  205 | Duration :   4.970 s
# Step :  135125 | Reward :  110 | Duration :   3.438 s
# Step :  135216 | Reward :   20 | Duration :   1.839 s
# Step :  135426 | Reward :   70 | Duration :   4.056 s
# Step :  135625 | Reward :   90 | Duration :   3.804 s
# Step :  135899 | Reward :  170 | Duration :   5.343 s
# Step :  136159 | Reward :  210 | Duration :   4.945 s
# Step :  136447 | Reward :  165 | Duration :   5.568 s
# Step :  136622 | Reward :   60 | Duration :   3.434 s
# Step :  136814 | Reward :   60 | Duration :   4.029 s
# Step :  137015 | Reward :   85 | Duration :   4.026 s
# Step :  137188 | Reward :   50 | Duration :   3.402 s
# Step :  137344 | Reward :   40 | Duration :   3.103 s

# %% [markdown]
# PPO training model on breakout

# %%
# !pip install gym -q
# !pip install torch -q
# !pip install numpy -q
# !pip install matplotlib -q

# %% [markdown]
# Remember to mount your drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import random
import cv2
import numpy as np
import gym
from gym import Wrapper

class CustomBreakout(Wrapper):
    def __init__(self, env, size=84, skip=4):
        super(CustomBreakout, self).__init__(env)
        self.skip = skip
        self.size = size
    
    def ProcessFrame(self, frame):
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (self.size, self.size)) / 255.0
        frame = np.expand_dims(frame, axis=0)
        return frame
    
    def step(self, action):
        total_reward = 0
        for _ in range(self.skip):
            state, reward, done, info = self.env.step(action)
            total_reward += reward
            
            if done:
                break
        state = self.ProcessFrame(state)
        return state, total_reward, done, info

    def reset(self):
        state = self.env.reset()
        state = self.ProcessFrame(state)
        return state
    
class CustomBreakout_stack(Wrapper):
    def __init__(self, env, size=84, skip=4):
        super(CustomBreakout_stack, self).__init__(env)
        self.skip = skip
        self.size = size
        self.history = []

    def ProcessFrame(self, frame):
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (self.size, self.size)) / 255.0
        return frame
    
    def step(self, action):
        total_reward = 0
        for _ in range(self.skip):
            state, reward, done, info = self.env.step(action)
            total_reward += reward
            
            if done==True:
                break

        state = self.ProcessFrame(state)

        self.history.append(state)
        del self.history[0]

        return np.stack(self.history), total_reward, done, info

    def reset(self):
        state = self.env.reset()
        state = self.ProcessFrame(state)
        self.history = [state, state, state, state]
        return np.stack(self.history)

def CreateBreakout(stack=True):
    env = gym.make('SpaceInvaders-v0')
    if stack:
        env = CustomBreakout_stack(env)
    else:
        env = CustomBreakout(env)
    return env

class MultipleBreakout:
    def __init__(self, N, stack=True):
        self.envs = [CreateBreakout(stack) for _ in range(N)]
    
    def reset(self):
        obs = []
        for env in self.envs:
            ob = env.reset()
            obs.append(ob)
        return np.stack(obs)
    
    def step(self, actions):
        obs, rewards, dones, infos = [], [], [], []
        for env, action in zip(self.envs, actions):
            ob, reward, done, info = env.step(action)
            if done:
                ob = env.reset()
            obs.append(ob)
            rewards.append(reward)
            dones.append(done)
            infos.append(info)
        return np.stack(obs), np.stack(rewards), np.stack(dones), info
    
    def render(self):
        for env in self.envs:
            env.render()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
from torch.distributions import Categorical

import numpy as np

class QNet(nn.Module):
    def __init__(self):
        super(QNet, self).__init__()

        # layers
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)

        self.ConvOutSize = self.get_conv_out_size()

        self.fc = nn.Linear(self.ConvOutSize * self.ConvOutSize * 64, 512)

        self.Q = nn.Linear(512, 4)

        self.initialize_weights()
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.view(-1, self.ConvOutSize * self.ConvOutSize * 64)

        x = F.relu(self.fc(x))
        q = self.Q(x)
        return q
    
    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)

    def get_conv_out_size(self):
        test_tensor = torch.FloatTensor(1, 4, 84, 84)
        out_tensor = self.conv3(self.conv2(self.conv1(test_tensor)))
        conv_out_size = out_tensor.size()[-1]
        return conv_out_size

class QNet_LSTM(nn.Module):
    def __init__(self):
        super(QNet_LSTM, self).__init__()

        # layers
        self.conv1 = nn.Conv2d(1, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)

        self.ConvOutSize = self.get_conv_out_size()

        self.lstm = nn.LSTMCell(self.ConvOutSize * self.ConvOutSize * 64, 512)

        self.Q = nn.Linear(512, 4)

        self.initialize_weights()
    
    def forward(self, x, hidden):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.view(-1, self.ConvOutSize * self.ConvOutSize * 64)

        h, c = self.lstm(x, hidden)

        q = self.Q(h)

        return q, (h, c)
    
    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.LSTMCell):
                nn.init.constant_(module.bias_ih, 0)
                nn.init.constant_(module.bias_hh, 0)

    def get_conv_out_size(self):
        test_tensor = torch.FloatTensor(1, 1, 84, 84)
        out_tensor = self.conv3(self.conv2(self.conv1(test_tensor)))
        conv_out_size = out_tensor.size()[-1]
        return conv_out_size

class ActorCriticNet(nn.Module):
    def __init__(self):
        super(ActorCriticNet, self).__init__()

        # layers
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)

        self.ConvOutSize = self.get_conv_out_size()

        self.fc = nn.Linear(self.ConvOutSize * self.ConvOutSize * 64, 512)

        self.Pi = nn.Linear(512, 4)
        self.V = nn.Linear(512, 1)

        self.initialize_weights()
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.view(-1, self.ConvOutSize * self.ConvOutSize * 64)

        x = F.relu(self.fc(x))

        prob = self.Pi(x)
        prob = F.softmax(prob, dim=-1)

        value = self.V(x)

        return prob, value
    
    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)

    def get_conv_out_size(self):
        test_tensor = torch.FloatTensor(1, 4, 84, 84)
        out_tensor = self.conv3(self.conv2(self.conv1(test_tensor)))
        conv_out_size = out_tensor.size()[-1]
        return conv_out_size

class ActorCriticNet_LSTM(nn.Module):
    def __init__(self):
        super(ActorCriticNet_LSTM, self).__init__()

        # layers
        self.conv1 = nn.Conv2d(1, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)

        self.ConvOutSize = self.get_conv_out_size()

        self.lstm = nn.LSTMCell(self.ConvOutSize * self.ConvOutSize * 64, 512)

        self.Pi = nn.Linear(512, 4)
        self.V = nn.Linear(512, 1)

        self.initialize_weights()
    
    def forward(self, x, hidden):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.view(-1, self.ConvOutSize * self.ConvOutSize * 64)

        h, c = self.lstm(x, hidden)

        prob = self.Pi(h)
        prob = F.softmax(prob, dim=-1)

        value = self.V(h)

        return prob, value, (h, c)
    
    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.LSTMCell):
                nn.init.constant_(module.bias_ih, 0)
                nn.init.constant_(module.bias_hh, 0)

    def get_conv_out_size(self):
        test_tensor = torch.FloatTensor(1, 1, 84, 84)
        out_tensor = self.conv3(self.conv2(self.conv1(test_tensor)))
        conv_out_size = out_tensor.size()[-1]
        return conv_out_size

# %%
#setting up the csv writer for logging
import csv
filename = './drive/MyDrive/ai_group/training_log_SpaceInvaders.csv'

# %%
#required imports

import torch
import torch.nn as nn
import torch.nn.functional as F 
from torch.distributions import Categorical

import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

#required for timing games
import time

# %%
# settings
Train_max_step         = 4000000
learning_rate          = 1e-4
gamma                  = 0.99
lambd                  = 0.95
eps_clip               = 0.1
K_epoch                = 10
N_worker               = 1
T_horizon              = 16
save_interval          = 250
model_path             = './drive/MyDrive/ai_group/Models/SpaceInvaders_PPO.model'
history_path           = './drive/MyDrive/ai_group/Train_Historys/SpaceInvaders_PPO'

# %%
#setup training function

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

def train(Net, optimizer, states, actions, rewards, next_states, dones, old_probs):
    states = torch.FloatTensor(states).view(-1, 4, 84, 84).to(device) # (T*N, 4, 84, 84)
    actions = torch.LongTensor(actions).view(-1, 1).to(device) # (T*N, 1)
    rewards = torch.FloatTensor(rewards).view(-1, 1).to(device) # (T*N, 1)
    next_states = torch.FloatTensor(next_states).view(-1, 4, 84, 84).to(device) # (T*N, 4, 84, 84)
    dones = torch.FloatTensor(dones).view(-1, 1).to(device) # (T*N, 1)
    old_probs = torch.FloatTensor(old_probs).view(-1, 1).to(device) # (T*N, 1)

    for _ in range(K_epoch):
        probs, values = Net(states) # (T*N, num_action), (T*N, 1)
        _, next_values = Net(next_states) # (T*N, 1)

        td_targets = rewards + gamma * next_values * dones #(T*N, 1)
        deltas = td_targets - values # (T*N, 1)

        # calculate GAE
        deltas = deltas.view(T_horizon, N_worker, 1).cpu().detach().numpy() #(T, N, 1)
        masks = dones.view(T_horizon, N_worker, 1).cpu().numpy()
        advantages = []
        advantage = 0
        for delta, mask in zip(deltas[::-1], masks[::-1]):
            advantage = gamma * lambd * advantage * mask + delta
            advantages.append(advantage)
        advantages.reverse()
        advantages = torch.FloatTensor(advantages).view(-1, 1).to(device) # (T*N, 1)

        probs_a = probs.gather(1, actions) #(T*N, 1)

        m = Categorical(probs)
        entropy = m.entropy()

        ratio = torch.exp(torch.log(probs_a) - torch.log(old_probs))
        surr1 = ratio * advantages
        surr2 = torch.clamp(ratio, 1-eps_clip, 1+eps_clip) * advantages

        actor_loss = -torch.mean(torch.min(surr1, surr2))
        critic_loss = F.smooth_l1_loss(values, td_targets.detach())
        entropy_loss = torch.mean(entropy)

        loss = actor_loss + critic_loss - 0.01 * entropy_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# cuda

# %% [markdown]
# Rember to uncomment the lines in the follwing block if you want to load a previous model state!!!

# %%
#define main training loop

def main():
    env = MultipleBreakout(N_worker)
    Net = ActorCriticNet().to(device)

    """
    Uncomment this line to load a previous model
    """
    Net.load_state_dict(torch.load(model_path))                  #Uncomment this line to load a previous model

    optimizer = torch.optim.Adam(Net.parameters(), learning_rate)

    scores = [0.0 for _ in range(N_worker)]
    score_history = []
    train_history = []
    reward_sum = []

    """
    Uncomment the next line if you want to load the previous model
    """  
    train_history = np.load(history_path+'.npy').tolist()        #Uncomment this line to load a previous model
    
    step = 0

    state = env.reset() # (N, 4, 84, 84)

    print("Train Start")
    start_time = time.perf_counter()

    while step <= Train_max_step:
        states, actions, rewards, next_states, dones, old_probs = list(), list(), list(), list(), list(), list()
        for _ in range(T_horizon):
            prob, _ = Net(torch.FloatTensor(state).to(device))
            m = Categorical(prob)

            action = m.sample() # (N,)
            old_prob = prob.gather(1, action.unsqueeze(1)) # (N, 1)

            action = action.cpu().detach().numpy()
            old_prob = old_prob.cpu().detach().numpy()

            next_state, reward, done, info = env.step(action)
            lives = info['ale.lives']
            reward_sum.append(reward)
            
            if lives == 0:
              end_time = time.perf_counter()
              dur = end_time - start_time
              start_time = end_time
              with open(filename, mode='a') as csv_file:
                csv_writer = csv.writer(csv_file, delimiter=',')
                csv_writer.writerow([step, int(sum(reward_sum)[0]), dur])
              dur_s = "{:.3f} s".format(dur)
              print("Step : {0:7} | Reward : {1:4} | Duration :".format(step, int(sum(reward_sum)[0])), 
                    dur_s.rjust(9,' '))
              reward_sum.clear()
              
 
            # save transition
            states.append(state) # (T, N, 4, 84, 84)
            actions.append(action) # (T, N)
            rewards.append(reward/10.0) # (T, N)
            next_states.append(next_state) # (T, N, 4, 84, 84)
            dones.append(1-done) # (T, N)
            old_probs.append(old_prob)# (T, N, 1)


            # record score and check done
            for i, (r, d) in enumerate(zip(reward, done)):
                scores[i] += r

                if d==True:
                    score_history.append(scores[i])
                    scores[i] = 0.0
                    if len(score_history) > 250:
                        del score_history[0]

            state = next_state

            step += 1

            if step % save_interval == 0:
                torch.save(Net.state_dict(), model_path)
                train_history.append(mean(score_history))
                np.save(history_path, np.array(train_history))
                 # print("step : {}, Average score of last 250 episode : {:.1f}".format(step, mean(score_history)))

        train(Net, optimizer, states, actions, rewards, next_states, dones, old_probs)

    torch.save(Net.state_dict(), model_path)
    np.save(history_path, np.array(train_history))
     # print("Train end, avg_score of last 100 episode : {}".format(mean(score_history)))

# %%
if __name__ == "__main__":
    main()
# Out:
# Train Start
# Step :     166 | Reward :  275 | Duration :   2.294 s
# Step :     414 | Reward :  340 | Duration :   3.331 s
# Step :     672 | Reward :  590 | Duration :   3.366 s
# Step :    1028 | Reward :  445 | Duration :   4.518 s
# Step :    1270 | Reward :  470 | Duration :   3.146 s
# Step :    1464 | Reward :  325 | Duration :   2.351 s
# Step :    1721 | Reward :  435 | Duration :   3.178 s
# Step :    1978 | Reward :  585 | Duration :   3.164 s
# Step :    2188 | Reward :  340 | Duration :   2.560 s
# Step :    2359 | Reward :  265 | Duration :   2.145 s
# Step :    2643 | Reward :  460 | Duration :   3.463 s
# Step :    2885 | Reward :  340 | Duration :   2.927 s
# Step :    3168 | Reward :  600 | Duration :   3.550 s
# Step :    3342 | Reward :  140 | Duration :   2.172 s
# Step :    3606 | Reward :  370 | Duration :   3.297 s
# Step :    3854 | Reward :  320 | Duration :   2.964 s
# Step :    4103 | Reward :  310 | Duration :   3.104 s
# Step :    4283 | Reward :  325 | Duration :   2.200 s
# Step :    4504 | Reward :  360 | Duration :   2.697 s
# Step :    4715 | Reward :  290 | Duration :   2.507 s
# Step :    4870 | Reward :  245 | Duration :   1.948 s
# Step :    4996 | Reward :  140 | Duration :   1.546 s
# Step :    5238 | Reward :  305 | Duration :   2.949 s
# Step :    5446 | Reward :  385 | Duration :   2.554 s
# Step :    5673 | Reward :  260 | Duration :   2.782 s
# Step :    5871 | Reward :  485 | Duration :   2.405 s
# Step :    6075 | Reward :  405 | Duration :   2.572 s
# Step :    6301 | Reward :  305 | Duration :   2.759 s
# Step :    6489 | Reward :  100 | Duration :   2.293 s
# Step :    6676 | Reward :  185 | Duration :   2.325 s
# Step :    6851 | Reward :  225 | Duration :   2.172 s
# Step :    7143 | Reward :  420 | Duration :   3.550 s
# Step :    7346 | Reward :  295 | Duration :   2.586 s
# Step :    7527 | Reward :  245 | Duration :   2.226 s
# Step :    7766 | Reward :  360 | Duration :   2.950 s
# Step :    7958 | Reward :  425 | Duration :   2.331 s
# Step :    8078 | Reward :   85 | Duration :   1.441 s
# Step :    8261 | Reward :  405 | Duration :   2.313 s
# Step :    8497 | Reward :  610 | Duration :   3.095 s
# Step :    8746 | Reward :  585 | Duration :   2.968 s
# Step :    8982 | Reward :  345 | Duration :   2.907 s
# Step :    9197 | Reward :  365 | Duration :   2.569 s
# Step :    9406 | Reward :  345 | Duration :   2.526 s
# Step :    9593 | Reward :  295 | Duration :   2.325 s
# Step :    9892 | Reward :  585 | Duration :   3.641 s
# Step :   10108 | Reward :  420 | Duration :   2.566 s
# Step :   10348 | Reward :  625 | Duration :   2.997 s
# Step :   10720 | Reward :  415 | Duration :   4.569 s
# Step :   10992 | Reward :  450 | Duration :   3.301 s
# Step :   11204 | Reward :  375 | Duration :   2.617 s
# Step :   11448 | Reward :  375 | Duration :   2.981 s
# Step :   11623 | Reward :  290 | Duration :   2.190 s
# Step :   11906 | Reward :  530 | Duration :   3.439 s
# Step :   12175 | Reward :  445 | Duration :   3.146 s
# Step :   12366 | Reward :  365 | Duration :   2.364 s
# Step :   12511 | Reward :   80 | Duration :   1.809 s
# Step :   12882 | Reward :  535 | Duration :   4.584 s
# Step :   13388 | Reward :  740 | Duration :   6.057 s
# Step :   13561 | Reward :   60 | Duration :   2.223 s
# Step :   13829 | Reward :  370 | Duration :   3.745 s
# Step :   14122 | Reward :  290 | Duration :   3.614 s
# Step :   14503 | Reward :  495 | Duration :   4.703 s
# Step :   14729 | Reward :  325 | Duration :   2.709 s
# Step :   14991 | Reward :  430 | Duration :   3.129 s
# Step :   15196 | Reward :  360 | Duration :   2.579 s
# Step :   15469 | Reward :  405 | Duration :   3.352 s
# Step :   15658 | Reward :  400 | Duration :   2.352 s
# Step :   15861 | Reward :  285 | Duration :   2.667 s
# Step :   16107 | Reward :  530 | Duration :   2.951 s
# Step :   16350 | Reward :  295 | Duration :   2.939 s
# Step :   16642 | Reward :  520 | Duration :   3.695 s
# Step :   16829 | Reward :  265 | Duration :   2.235 s
# Step :   17086 | Reward :  310 | Duration :   3.161 s
# Step :   17312 | Reward :  300 | Duration :   2.891 s
# Step :   17501 | Reward :  180 | Duration :   2.225 s
# Step :   17632 | Reward :  170 | Duration :   1.725 s
# Step :   17877 | Reward :  250 | Duration :   3.009 s
# Step :   18002 | Reward :  110 | Duration :   1.620 s
# Step :   18155 | Reward :  125 | Duration :   1.802 s
# Step :   18324 | Reward :  105 | Duration :   2.188 s
# Step :   18591 | Reward :  230 | Duration :   3.187 s
# Step :   18859 | Reward :  300 | Duration :   3.400 s
# Step :   19023 | Reward :  195 | Duration :   2.001 s
# Step :   19246 | Reward :  295 | Duration :   2.804 s
# Step :   19512 | Reward :  290 | Duration :   3.348 s
# Step :   19668 | Reward :  190 | Duration :   1.951 s
# Step :   19810 | Reward :  105 | Duration :   1.766 s
# Step :   20084 | Reward :  290 | Duration :   3.360 s
# Step :   20225 | Reward :  115 | Duration :   1.764 s
# Step :   20374 | Reward :  125 | Duration :   1.819 s
# Step :   20524 | Reward :  185 | Duration :   1.828 s
# Step :   20687 | Reward :  210 | Duration :   1.965 s
# Step :   20985 | Reward :  400 | Duration :   4.049 s
# Step :   21189 | Reward :  190 | Duration :   2.602 s
# Step :   21338 | Reward :  150 | Duration :   1.866 s
# Step :   21583 | Reward :  290 | Duration :   2.968 s
# Step :   21716 | Reward :  180 | Duration :   1.752 s
# Step :   22009 | Reward :  350 | Duration :   3.585 s
# Step :   22181 | Reward :  165 | Duration :   2.147 s
# Step :   22375 | Reward :  280 | Duration :   2.387 s
# Step :   22633 | Reward :  355 | Duration :   3.351 s
# Step :   22814 | Reward :  225 | Duration :   2.213 s
# Step :   22974 | Reward :  290 | Duration :   1.973 s
# Step :   23145 | Reward :  215 | Duration :   2.162 s
# Step :   23511 | Reward :  425 | Duration :   4.468 s
# Step :   23770 | Reward :  420 | Duration :   3.173 s
# Step :   23997 | Reward :  285 | Duration :   2.730 s
# Step :   24224 | Reward :  315 | Duration :   2.926 s
# Step :   24405 | Reward :  160 | Duration :   2.507 s
# Step :   24576 | Reward :  285 | Duration :   2.192 s
# Step :   24783 | Reward :  335 | Duration :   2.436 s
# Step :   25026 | Reward :  405 | Duration :   3.122 s
# Step :   25234 | Reward :  310 | Duration :   2.526 s
# Step :   25438 | Reward :  270 | Duration :   2.426 s
# Step :   25727 | Reward :  280 | Duration :   3.530 s
# Step :   25923 | Reward :  185 | Duration :   2.525 s
# Step :   26140 | Reward :  275 | Duration :   3.034 s
# Step :   26339 | Reward :  220 | Duration :   2.537 s
# Step :   26521 | Reward :  220 | Duration :   2.232 s
# Step :   26707 | Reward :  180 | Duration :   2.346 s
# Step :   26999 | Reward :  190 | Duration :   3.628 s
# Step :   27181 | Reward :  110 | Duration :   2.257 s
# Step :   27446 | Reward :  230 | Duration :   3.366 s
# Step :   27680 | Reward :  310 | Duration :   2.946 s
# Step :   27794 | Reward :  185 | Duration :   1.640 s
# Step :   27918 | Reward :  140 | Duration :   1.388 s
# Step :   28099 | Reward :  235 | Duration :   2.341 s
# Step :   28289 | Reward :  395 | Duration :   2.372 s
# Step :   28532 | Reward :  440 | Duration :   2.993 s
# Step :   28780 | Reward :  305 | Duration :   2.969 s
# Step :   28897 | Reward :  170 | Duration :   1.530 s
# Step :   29141 | Reward :  380 | Duration :   2.955 s
# Step :   29367 | Reward :  320 | Duration :   2.786 s
# Step :   29666 | Reward :  390 | Duration :   3.738 s
# Step :   29887 | Reward :  290 | Duration :   2.652 s
# Step :   30054 | Reward :  160 | Duration :   2.189 s
# Step :   30302 | Reward :  385 | Duration :   2.999 s
# Step :   30564 | Reward :  345 | Duration :   3.342 s
# Step :   30733 | Reward :  205 | Duration :   2.011 s
# Step :   30966 | Reward :  570 | Duration :   2.971 s
# Step :   31172 | Reward :  290 | Duration :   2.576 s
# Step :   31386 | Reward :  345 | Duration :   2.753 s
# Step :   31555 | Reward :  160 | Duration :   2.186 s
# Step :   31748 | Reward :  270 | Duration :   2.358 s
# Step :   31998 | Reward :  555 | Duration :   2.946 s
# Step :   32173 | Reward :  155 | Duration :   2.217 s
# Step :   32630 | Reward :  580 | Duration :   5.671 s
# Step :   32876 | Reward :  330 | Duration :   3.010 s
# Step :   33041 | Reward :  120 | Duration :   2.396 s
# Step :   33306 | Reward :  475 | Duration :   3.173 s
# Step :   33509 | Reward :  235 | Duration :   2.553 s
# Step :   33771 | Reward :  500 | Duration :   3.184 s
# Step :   34022 | Reward :  320 | Duration :   3.111 s
# Step :   34192 | Reward :  230 | Duration :   2.143 s
# Step :   34375 | Reward :  345 | Duration :   2.210 s
# Step :   34599 | Reward :  345 | Duration :   2.779 s
# Step :   34818 | Reward :  250 | Duration :   2.932 s
# Step :   35087 | Reward :  235 | Duration :   3.197 s
# Step :   35323 | Reward :  305 | Duration :   2.925 s
# Step :   35588 | Reward :  295 | Duration :   3.330 s
# Step :   35866 | Reward :  195 | Duration :   3.414 s
# Step :   36110 | Reward :  250 | Duration :   2.953 s
# Step :   36280 | Reward :  240 | Duration :   2.174 s
# Step :   36548 | Reward :  390 | Duration :   3.318 s
# Step :   36832 | Reward :  500 | Duration :   3.482 s
# Step :   37125 | Reward :  755 | Duration :   3.548 s
# Step :   37298 | Reward :  190 | Duration :   2.190 s
# Step :   37526 | Reward :  290 | Duration :   2.782 s
# Step :   37749 | Reward :  335 | Duration :   2.756 s
# Step :   38022 | Reward :  490 | Duration :   3.358 s
# Step :   38397 | Reward :  575 | Duration :   4.489 s
# Step :   38591 | Reward :  350 | Duration :   2.408 s
# Step :   38741 | Reward :  210 | Duration :   1.982 s
# Step :   38990 | Reward :  440 | Duration :   3.011 s
# Step :   39217 | Reward :  370 | Duration :   2.915 s
# Step :   39404 | Reward :  260 | Duration :   2.234 s
# Step :   39678 | Reward :  545 | Duration :   3.323 s
# Step :   39919 | Reward :  460 | Duration :   2.990 s
# Step :   40156 | Reward :  410 | Duration :   2.993 s
# Step :   40454 | Reward :  400 | Duration :   3.942 s
# Step :   40585 | Reward :  230 | Duration :   1.641 s
# Step :   40827 | Reward :  420 | Duration :   2.991 s
# Step :   41061 | Reward :  320 | Duration :   2.934 s
# Step :   41289 | Reward :  330 | Duration :   2.760 s
# Step :   41532 | Reward :  285 | Duration :   2.938 s
# Step :   41852 | Reward :  470 | Duration :   3.902 s
# Step :   42068 | Reward :  350 | Duration :   2.761 s
# Step :   42277 | Reward :  305 | Duration :   2.542 s
# Step :   42530 | Reward :  570 | Duration :   3.082 s
# Step :   42695 | Reward :  320 | Duration :   1.946 s
# Step :   42874 | Reward :  365 | Duration :   2.179 s
# Step :   43213 | Reward :  575 | Duration :   4.114 s
# Step :   43407 | Reward :  415 | Duration :   2.407 s
# Step :   43660 | Reward :  600 | Duration :   3.127 s
# Step :   44044 | Reward :  480 | Duration :   4.651 s
# Step :   44236 | Reward :  305 | Duration :   2.338 s
# Step :   44442 | Reward :  215 | Duration :   2.573 s
# Step :   44617 | Reward :  185 | Duration :   2.219 s
# Step :   44827 | Reward :  440 | Duration :   2.563 s
# Step :   45081 | Reward :  455 | Duration :   3.145 s
# Step :   45324 | Reward :  315 | Duration :   3.002 s
# Step :   45654 | Reward :  575 | Duration :   4.360 s
# Step :   45857 | Reward :  350 | Duration :   2.572 s
# Step :   46095 | Reward :  550 | Duration :   2.837 s
# Step :   46303 | Reward :  275 | Duration :   2.612 s
# Step :   46527 | Reward :  360 | Duration :   2.767 s
# Step :   46756 | Reward :  380 | Duration :   2.955 s
# Step :   46956 | Reward :  250 | Duration :   2.380 s
# Step :   47198 | Reward :  280 | Duration :   2.912 s
# Step :   47394 | Reward :  335 | Duration :   2.861 s
# Step :   47602 | Reward :  335 | Duration :   2.553 s
# Step :   47830 | Reward :  270 | Duration :   2.811 s
# Step :   48199 | Reward :  320 | Duration :   4.476 s
# Step :   48449 | Reward :  305 | Duration :   3.123 s
# Step :   48677 | Reward :  580 | Duration :   2.748 s
# Step :   48872 | Reward :  415 | Duration :   2.369 s
# Step :   49066 | Reward :  360 | Duration :   2.615 s
# Step :   49312 | Reward :  305 | Duration :   3.104 s
# Step :   49521 | Reward :  300 | Duration :   2.548 s
# Step :   49823 | Reward :  525 | Duration :   3.504 s
# Step :   50047 | Reward :  315 | Duration :   2.715 s
# Step :   50172 | Reward :  180 | Duration :   1.572 s
# Step :   50367 | Reward :  380 | Duration :   2.395 s
# Step :   50561 | Reward :  295 | Duration :   2.494 s
# Step :   50819 | Reward :  385 | Duration :   3.474 s
# Step :   51032 | Reward :  375 | Duration :   2.557 s
# Step :   51234 | Reward :  290 | Duration :   2.547 s
# Step :   51393 | Reward :  105 | Duration :   2.013 s
# Step :   51549 | Reward :  190 | Duration :   1.853 s
# Step :   51772 | Reward :  380 | Duration :   2.792 s
# Step :   52086 | Reward :  430 | Duration :   3.923 s
# Step :   52323 | Reward :  360 | Duration :   2.932 s
# Step :   52532 | Reward :  395 | Duration :   2.550 s
# Step :   52790 | Reward :  430 | Duration :   3.124 s
# Step :   52966 | Reward :  205 | Duration :   2.144 s
# Step :   53185 | Reward :  215 | Duration :   2.761 s
# Step :   53422 | Reward :  320 | Duration :   2.806 s
# Step :   53664 | Reward :  365 | Duration :   3.134 s
# Step :   53825 | Reward :  255 | Duration :   2.005 s
# Step :   54049 | Reward :  315 | Duration :   2.758 s
# Step :   54296 | Reward :  305 | Duration :   2.950 s
# Step :   54469 | Reward :  260 | Duration :   2.131 s
# Step :   54754 | Reward :  300 | Duration :   3.560 s
# Step :   54930 | Reward :  260 | Duration :   2.132 s
# Step :   55264 | Reward :  945 | Duration :   4.093 s
# Step :   55453 | Reward :  285 | Duration :   2.169 s
# Step :   55638 | Reward :  370 | Duration :   2.356 s
# Step :   55840 | Reward :  285 | Duration :   2.515 s
# Step :   56061 | Reward :  435 | Duration :   2.611 s
# Step :   56263 | Reward :  390 | Duration :   2.549 s
# Step :   56471 | Reward :  585 | Duration :   2.551 s
# Step :   56702 | Reward :  325 | Duration :   2.802 s
# Step :   57022 | Reward :  600 | Duration :   3.852 s
# Step :   57253 | Reward :  280 | Duration :   2.867 s
# Step :   57508 | Reward :  605 | Duration :   3.125 s
# Step :   57833 | Reward :  445 | Duration :   3.905 s
# Step :   58039 | Reward :  575 | Duration :   2.662 s
# Step :   58314 | Reward :  490 | Duration :   3.315 s
# Step :   58537 | Reward :  320 | Duration :   2.784 s
# Step :   58747 | Reward :  365 | Duration :   2.513 s
# Step :   58986 | Reward :  270 | Duration :   2.921 s
# Step :   59171 | Reward :  285 | Duration :   2.351 s
# Step :   59426 | Reward :  535 | Duration :   3.143 s
# Step :   59640 | Reward :  295 | Duration :   2.612 s
# Step :   59890 | Reward :  570 | Duration :   3.116 s
# Step :   60095 | Reward :  550 | Duration :   2.405 s
# Step :   60289 | Reward :  385 | Duration :   2.509 s
# Step :   60462 | Reward :  290 | Duration :   1.971 s
# Step :   60778 | Reward :  575 | Duration :   3.891 s
# Step :   60973 | Reward :  400 | Duration :   2.310 s
# Step :   61162 | Reward :  220 | Duration :   2.332 s
# Step :   61362 | Reward :  290 | Duration :   2.541 s
# Step :   61627 | Reward :  690 | Duration :   3.155 s
# Step :   61898 | Reward :  240 | Duration :   3.307 s
# Step :   62136 | Reward :  410 | Duration :   2.903 s
# Step :   62398 | Reward :  325 | Duration :   3.115 s
# Step :   62643 | Reward :  260 | Duration :   3.066 s
# Step :   62867 | Reward :  550 | Duration :   2.763 s
# Step :   63158 | Reward :  395 | Duration :   3.491 s
# Step :   63379 | Reward :  305 | Duration :   2.848 s
# Step :   63742 | Reward :  480 | Duration :   4.237 s
# Step :   63967 | Reward :  410 | Duration :   2.715 s
# Step :   64180 | Reward :  305 | Duration :   2.719 s
# Step :   64391 | Reward :  455 | Duration :   2.571 s
# Step :   64645 | Reward :  530 | Duration :   3.081 s
# Step :   64888 | Reward :  390 | Duration :   2.921 s
# Step :   65061 | Reward :  225 | Duration :   2.462 s
# Step :   65303 | Reward :  390 | Duration :   2.919 s
# Step :   65603 | Reward :  445 | Duration :   3.681 s
# Step :   65828 | Reward :  415 | Duration :   2.732 s
# Step :   66038 | Reward :  390 | Duration :   2.549 s
# Step :   66362 | Reward :  395 | Duration :   3.900 s
# Step :   66574 | Reward :  390 | Duration :   2.575 s
# Step :   66802 | Reward :  390 | Duration :   2.895 s
# Step :   67030 | Reward :  390 | Duration :   2.750 s
# Step :   67227 | Reward :  380 | Duration :   2.348 s
# Step :   67415 | Reward :  290 | Duration :   2.382 s
# Step :   67599 | Reward :  485 | Duration :   2.208 s
# Step :   67841 | Reward :  310 | Duration :   3.081 s
# Step :   68107 | Reward :  540 | Duration :   3.116 s
# Step :   68351 | Reward :  520 | Duration :   2.916 s
# Step :   68537 | Reward :  275 | Duration :   2.338 s
# Step :   68740 | Reward :  350 | Duration :   2.637 s
# Step :   69064 | Reward :  770 | Duration :   3.882 s
# Step :   69184 | Reward :  215 | Duration :   1.533 s
# Step :   69317 | Reward :  210 | Duration :   1.605 s
# Step :   69550 | Reward :  345 | Duration :   2.748 s
# Step :   69887 | Reward :  525 | Duration :   4.104 s
# Step :   70049 | Reward :  230 | Duration :   2.152 s
# Step :   70260 | Reward :  325 | Duration :   2.597 s
# Step :   70633 | Reward :  685 | Duration :   4.600 s
# Step :   71023 | Reward :  545 | Duration :   4.638 s
# Step :   71322 | Reward :  725 | Duration :   3.685 s
# Step :   71523 | Reward :  550 | Duration :   2.533 s
# Step :   71751 | Reward :  285 | Duration :   2.786 s
# Step :   71967 | Reward :  395 | Duration :   2.536 s
# Step :   72150 | Reward :  270 | Duration :   2.319 s
# Step :   72436 | Reward :  415 | Duration :   3.527 s
# Step :   72780 | Reward :  470 | Duration :   4.130 s
# Step :   72905 | Reward :  170 | Duration :   1.557 s
# Step :   73040 | Reward :  165 | Duration :   1.763 s
# Step :   73226 | Reward :  190 | Duration :   2.191 s
# Step :   73448 | Reward :  335 | Duration :   2.752 s
# Step :   73695 | Reward :  415 | Duration :   2.919 s
# Step :   73820 | Reward :  140 | Duration :   1.591 s
# Step :   73996 | Reward :  315 | Duration :   2.160 s
# Step :   74205 | Reward :  290 | Duration :   2.550 s
# Step :   74470 | Reward :  420 | Duration :   3.290 s
# Step :   74782 | Reward :  480 | Duration :   3.707 s
# Step :   75049 | Reward :  420 | Duration :   3.275 s
# Step :   75257 | Reward :  450 | Duration :   2.564 s
# Step :   75482 | Reward :  305 | Duration :   2.712 s
# Step :   75674 | Reward :  215 | Duration :   2.361 s
# Step :   75952 | Reward :  295 | Duration :   3.462 s
# Step :   76265 | Reward :  610 | Duration :   3.720 s
# Step :   76418 | Reward :  245 | Duration :   1.934 s
# Step :   76621 | Reward :  595 | Duration :   2.484 s
# Step :   76915 | Reward :  410 | Duration :   3.697 s
# Step :   77119 | Reward :  280 | Duration :   2.430 s
# Step :   77408 | Reward :  410 | Duration :   3.679 s
# Step :   77712 | Reward :  800 | Duration :   3.679 s
# Step :   77962 | Reward :  395 | Duration :   3.015 s
# Step :   78456 | Reward : 1040 | Duration :   6.244 s
# Step :   78762 | Reward :  600 | Duration :   3.658 s
# Step :   79020 | Reward :  270 | Duration :   3.103 s
# Step :   79231 | Reward :  320 | Duration :   2.528 s
# Step :   79514 | Reward :  495 | Duration :   3.784 s
# Step :   79821 | Reward :  270 | Duration :   3.732 s
# Step :   80153 | Reward :  570 | Duration :   4.064 s
# Step :   80367 | Reward :  320 | Duration :   2.550 s
# Step :   80587 | Reward :  280 | Duration :   2.780 s
# Step :   80780 | Reward :  360 | Duration :   2.369 s
# Step :   81080 | Reward :  500 | Duration :   3.666 s
# Step :   81302 | Reward :  340 | Duration :   2.910 s
# Step :   81487 | Reward :  280 | Duration :   2.169 s
# Step :   81625 | Reward :  110 | Duration :   1.764 s
# Step :   81871 | Reward :  345 | Duration :   2.914 s
# Step :   82118 | Reward :  400 | Duration :   3.071 s
# Step :   82485 | Reward :  800 | Duration :   4.362 s
# Step :   82714 | Reward :  335 | Duration :   2.748 s
# Step :   83010 | Reward :  445 | Duration :   4.096 s
# Step :   83266 | Reward :  415 | Duration :   3.105 s
# Step :   83506 | Reward :  580 | Duration :   3.000 s
# Step :   83782 | Reward :  485 | Duration :   3.297 s
# Step :   84012 | Reward :  385 | Duration :   2.743 s
# Step :   84273 | Reward :  370 | Duration :   5.223 s
# Step :   84444 | Reward :  255 | Duration :   3.175 s
# Step :   84773 | Reward :  475 | Duration :   4.808 s
# Step :   85062 | Reward :  600 | Duration :   3.425 s
# Step :   85318 | Reward :  215 | Duration :   3.129 s
# Step :   85581 | Reward :  450 | Duration :   3.173 s
# Step :   85847 | Reward :  285 | Duration :   3.324 s
# Step :   86205 | Reward :  735 | Duration :   4.298 s
# Step :   86451 | Reward :  420 | Duration :   3.064 s
# Step :   86617 | Reward :  340 | Duration :   2.037 s
# Step :   86808 | Reward :  290 | Duration :   2.342 s
# Step :   87034 | Reward :  395 | Duration :   2.730 s
# Step :   87272 | Reward :  570 | Duration :   2.884 s
# Step :   87601 | Reward :  550 | Duration :   4.002 s
# Step :   87794 | Reward :  300 | Duration :   2.362 s
# Step :   88027 | Reward :  380 | Duration :   2.745 s
# Step :   88338 | Reward :  470 | Duration :   3.815 s
# Step :   88518 | Reward :  215 | Duration :   2.218 s
# Step :   88756 | Reward :  585 | Duration :   2.950 s
# Step :   88982 | Reward :  315 | Duration :   2.695 s
# Step :   89291 | Reward :  600 | Duration :   3.710 s
# Step :   89527 | Reward :  370 | Duration :   2.896 s
# Step :   89753 | Reward :  405 | Duration :   2.733 s
# Step :   90031 | Reward :  425 | Duration :   3.294 s
# Step :   90237 | Reward :  415 | Duration :   2.500 s
# Step :   90448 | Reward :  610 | Duration :   2.728 s
# Step :   90715 | Reward :  395 | Duration :   3.147 s
# Step :   91121 | Reward :  745 | Duration :   4.991 s
# Step :   91316 | Reward :  265 | Duration :   2.436 s
# Step :   91531 | Reward :  350 | Duration :   2.627 s
# Step :   91730 | Reward :  270 | Duration :   2.495 s
# Step :   91956 | Reward :  465 | Duration :   2.765 s
# Step :   92306 | Reward : 1000 | Duration :   4.450 s
# Step :   92547 | Reward :  365 | Duration :   2.952 s
# Step :   92782 | Reward :  285 | Duration :   2.800 s
# Step :   93008 | Reward :  265 | Duration :   2.893 s
# Step :   93185 | Reward :  170 | Duration :   2.116 s
# Step :   93440 | Reward :  430 | Duration :   3.115 s
# Step :   93649 | Reward :  335 | Duration :   2.575 s
# Step :   93852 | Reward :  370 | Duration :   2.658 s
# Step :   94088 | Reward :  325 | Duration :   3.012 s
# Step :   94327 | Reward :  340 | Duration :   2.935 s
# Step :   94512 | Reward :  335 | Duration :   2.374 s
# Step :   94744 | Reward :  390 | Duration :   2.745 s
# Step :   94957 | Reward :  390 | Duration :   2.579 s
# Step :   95188 | Reward :  580 | Duration :   2.942 s
# Step :   95401 | Reward :  475 | Duration :   2.569 s
# Step :   95613 | Reward :  315 | Duration :   2.851 s
# Step :   95842 | Reward :  235 | Duration :   2.888 s
# Step :   96030 | Reward :  285 | Duration :   2.194 s
# Step :   96308 | Reward :  355 | Duration :   3.463 s
# Step :   96560 | Reward :  410 | Duration :   3.101 s
# Step :   96748 | Reward :  240 | Duration :   2.182 s
# Step :   96983 | Reward :  330 | Duration :   2.910 s
# Step :   97236 | Reward :  450 | Duration :   3.090 s
# Step :   97476 | Reward :  300 | Duration :   3.091 s
# Step :   97670 | Reward :  250 | Duration :   2.375 s
# Step :   97976 | Reward :  370 | Duration :   3.731 s
# Step :   98165 | Reward :  205 | Duration :   2.365 s
# Step :   98357 | Reward :  220 | Duration :   2.362 s
# Step :   98659 | Reward :  700 | Duration :   3.701 s
# Step :   98886 | Reward :  295 | Duration :   2.788 s
# Step :   99014 | Reward :  155 | Duration :   1.601 s
# Step :   99246 | Reward :  350 | Duration :   2.899 s
# Step :   99476 | Reward :  285 | Duration :   2.928 s
# Step :   99756 | Reward :  685 | Duration :   3.369 s
# Step :   99975 | Reward :  335 | Duration :   2.687 s
# Step :  100252 | Reward :  380 | Duration :   3.377 s
# Step :  100524 | Reward :  540 | Duration :   3.264 s
# Step :  100795 | Reward :  325 | Duration :   3.311 s
# Step :  100985 | Reward :  250 | Duration :   2.323 s
# Step :  101191 | Reward :  205 | Duration :   2.573 s
# Step :  101553 | Reward :  715 | Duration :   4.592 s
# Step :  101688 | Reward :  135 | Duration :   1.621 s
# Step :  101810 | Reward :  185 | Duration :   1.591 s
# Step :  102035 | Reward :  290 | Duration :   2.790 s
# Step :  102210 | Reward :  260 | Duration :   2.175 s
# Step :  102388 | Reward :  220 | Duration :   2.206 s
# Step :  102627 | Reward :  315 | Duration :   2.933 s
# Step :  102786 | Reward :  215 | Duration :   1.996 s
# Step :  103037 | Reward :  290 | Duration :   2.967 s
# Step :  103248 | Reward :  275 | Duration :   2.659 s
# Step :  103584 | Reward :  490 | Duration :   4.045 s
# Step :  103810 | Reward :  345 | Duration :   2.713 s
# Step :  104041 | Reward :  310 | Duration :   2.764 s
# Step :  104396 | Reward :  600 | Duration :   4.229 s
# Step :  104677 | Reward :  500 | Duration :   3.625 s
# Step :  104901 | Reward :  315 | Duration :   2.760 s
# Step :  105084 | Reward :  260 | Duration :   2.241 s
# Step :  105411 | Reward :  550 | Duration :   4.060 s
# Step :  105545 | Reward :   85 | Duration :   1.630 s
# Step :  105667 | Reward :  145 | Duration :   1.535 s
# Step :  105803 | Reward :  115 | Duration :   1.626 s
# Step :  106046 | Reward :  280 | Duration :   2.948 s
# Step :  106206 | Reward :  150 | Duration :   1.990 s
# Step :  106531 | Reward :  450 | Duration :   4.104 s
# Step :  106934 | Reward :  870 | Duration :   4.870 s
# Step :  107179 | Reward :  315 | Duration :   2.927 s
# Step :  107373 | Reward :  240 | Duration :   2.398 s
# Step :  107678 | Reward :  485 | Duration :   3.712 s
# Step :  107847 | Reward :  215 | Duration :   2.167 s
# Step :  108067 | Reward :  315 | Duration :   2.909 s
# Step :  108304 | Reward :  365 | Duration :   2.912 s
# Step :  108536 | Reward :  265 | Duration :   2.791 s
# Step :  108738 | Reward :  225 | Duration :   2.499 s
# Step :  109055 | Reward :  570 | Duration :   3.715 s
# Step :  109341 | Reward :  575 | Duration :   3.485 s
# Step :  109619 | Reward :  290 | Duration :   3.494 s
# Step :  109872 | Reward :  385 | Duration :   3.425 s
# Step :  110113 | Reward :  555 | Duration :   2.911 s
# Step :  110423 | Reward :  605 | Duration :   3.698 s
# Step :  110626 | Reward :  215 | Duration :   2.561 s
# Step :  110765 | Reward :  170 | Duration :   1.624 s
# Step :  110942 | Reward :  225 | Duration :   2.163 s
# Step :  111175 | Reward :  290 | Duration :   2.953 s
# Step :  111365 | Reward :  515 | Duration :   2.337 s
# Step :  111583 | Reward :  330 | Duration :   2.809 s
# Step :  111891 | Reward :  385 | Duration :   3.883 s
# Step :  112274 | Reward :  545 | Duration :   4.704 s
# Step :  112396 | Reward :  180 | Duration :   1.435 s
# Step :  112617 | Reward :  365 | Duration :   2.813 s
# Step :  112900 | Reward :  560 | Duration :   3.543 s
# Step :  113198 | Reward :  620 | Duration :   3.576 s
# Step :  113432 | Reward :  350 | Duration :   2.945 s
# Step :  113677 | Reward :  355 | Duration :   2.970 s
# Step :  113926 | Reward :  385 | Duration :   3.108 s
# Step :  114158 | Reward :  535 | Duration :   2.773 s
# Step :  114445 | Reward :  330 | Duration :   3.507 s
# Step :  114717 | Reward :  435 | Duration :   3.296 s
# Step :  114987 | Reward :  435 | Duration :   3.262 s
# Step :  115151 | Reward :   95 | Duration :   2.056 s
# Step :  115429 | Reward :  405 | Duration :   3.634 s
# Step :  115717 | Reward :  440 | Duration :   3.544 s
# Step :  115943 | Reward :  625 | Duration :   2.791 s
# Step :  116161 | Reward :  405 | Duration :   2.733 s
# Step :  116408 | Reward :  665 | Duration :   2.957 s
# Step :  116615 | Reward :  380 | Duration :   2.554 s
# Step :  116816 | Reward :  295 | Duration :   2.549 s
# Step :  116980 | Reward :  180 | Duration :   1.974 s
# Step :  117275 | Reward :  455 | Duration :   3.687 s
# Step :  117518 | Reward :  420 | Duration :   2.996 s
# Step :  117767 | Reward :  415 | Duration :   3.105 s
# Step :  118076 | Reward :  475 | Duration :   3.690 s
# Step :  118281 | Reward :  330 | Duration :   2.624 s
# Step :  118481 | Reward :  315 | Duration :   2.486 s
# Step :  118719 | Reward :  525 | Duration :   2.795 s
# Step :  118912 | Reward :  385 | Duration :   2.517 s
# Step :  119210 | Reward :  545 | Duration :   3.538 s
# Step :  119358 | Reward :   95 | Duration :   1.853 s
# Step :  119587 | Reward :  325 | Duration :   2.941 s
# Step :  119910 | Reward :  350 | Duration :   3.949 s
# Step :  120040 | Reward :  215 | Duration :   1.598 s
# Step :  120264 | Reward :  540 | Duration :   2.760 s
# Step :  120450 | Reward :  540 | Duration :   2.314 s
# Step :  120656 | Reward :  280 | Duration :   2.700 s
# Step :  120884 | Reward :  305 | Duration :   2.770 s
# Step :  121108 | Reward :  335 | Duration :   2.719 s
# Step :  121306 | Reward :  315 | Duration :   2.389 s
# Step :  121540 | Reward :  535 | Duration :   2.919 s
# Step :  121816 | Reward :  380 | Duration :   3.343 s
# Step :  122026 | Reward :  370 | Duration :   2.577 s
# Step :  122397 | Reward :  490 | Duration :   4.774 s
# Step :  122571 | Reward :  200 | Duration :   2.150 s
# Step :  122783 | Reward :  365 | Duration :   2.544 s
# Step :  123036 | Reward :  370 | Duration :   3.103 s
# Step :  123283 | Reward :  540 | Duration :   3.117 s
# Step :  123412 | Reward :  105 | Duration :   1.582 s
# Step :  123651 | Reward :  390 | Duration :   2.937 s
# Step :  123911 | Reward :  415 | Duration :   3.112 s
# Step :  124136 | Reward :  375 | Duration :   3.013 s
# Step :  124367 | Reward :  345 | Duration :   2.745 s
# Step :  124597 | Reward :  335 | Duration :   2.884 s
# Step :  124842 | Reward :  305 | Duration :   2.940 s
# Step :  125051 | Reward :  405 | Duration :   2.574 s
# Step :  125279 | Reward :  275 | Duration :   2.782 s
# Step :  125679 | Reward :  625 | Duration :   4.802 s
# Step :  125976 | Reward :  545 | Duration :   3.662 s
# Step :  126323 | Reward :  465 | Duration :   4.374 s
# Step :  126560 | Reward :  425 | Duration :   2.941 s
# Step :  126787 | Reward :  365 | Duration :   2.853 s
# Step :  127036 | Reward :  335 | Duration :   2.945 s
# Step :  127163 | Reward :  240 | Duration :   1.556 s
# Step :  127296 | Reward :  190 | Duration :   1.748 s
# Step :  127429 | Reward :  125 | Duration :   1.570 s
# Step :  127649 | Reward :  270 | Duration :   2.740 s
# Step :  127826 | Reward :  240 | Duration :   2.293 s
# Step :  128004 | Reward :  340 | Duration :   2.183 s
# Step :  128310 | Reward :  335 | Duration :   3.686 s
# Step :  128566 | Reward :  325 | Duration :   3.118 s
# Step :  128753 | Reward :  240 | Duration :   2.354 s
# Step :  128926 | Reward :  205 | Duration :   2.003 s
# Step :  129131 | Reward :  290 | Duration :   2.536 s
# Step :  129252 | Reward :  185 | Duration :   1.588 s
# Step :  129472 | Reward :  235 | Duration :   2.910 s
# Step :  129669 | Reward :  395 | Duration :   2.351 s
# Step :  129985 | Reward :  430 | Duration :   3.841 s
# Step :  130306 | Reward :  465 | Duration :   3.890 s
# Step :  130504 | Reward :  565 | Duration :   2.364 s
# Step :  130728 | Reward :  320 | Duration :   2.777 s
# Step :  131057 | Reward :  975 | Duration :   4.067 s
# Step :  131247 | Reward :  320 | Duration :   2.185 s
# Step :  131510 | Reward :  275 | Duration :   3.345 s
# Step :  131695 | Reward :  235 | Duration :   2.201 s
# Step :  131828 | Reward :  150 | Duration :   1.784 s
# Step :  132062 | Reward :  475 | Duration :   2.758 s
# Step :  132276 | Reward :  355 | Duration :   2.723 s
# Step :  132453 | Reward :  250 | Duration :   2.114 s
# Step :  132787 | Reward :  465 | Duration :   4.079 s
# Step :  133048 | Reward :  415 | Duration :   3.256 s
# Step :  133288 | Reward :  440 | Duration :   2.926 s
# Step :  133579 | Reward :  675 | Duration :   3.485 s
# Step :  133866 | Reward :  385 | Duration :   3.497 s
# Step :  134178 | Reward :  640 | Duration :   3.841 s
# Step :  134416 | Reward :  460 | Duration :   2.960 s
# Step :  134615 | Reward :  285 | Duration :   2.424 s
# Step :  134842 | Reward :  365 | Duration :   3.018 s
# Step :  135062 | Reward :  430 | Duration :   2.679 s
# Step :  135292 | Reward :  365 | Duration :   2.712 s
# Step :  135626 | Reward :  810 | Duration :   4.042 s
# Step :  135830 | Reward :  255 | Duration :   2.535 s
# Step :  136018 | Reward :  265 | Duration :   2.341 s
# Step :  136444 | Reward :  575 | Duration :   4.977 s
# Step :  136681 | Reward :  525 | Duration :   3.192 s
# Step :  136902 | Reward :  365 | Duration :   2.723 s
# Step :  137125 | Reward :  395 | Duration :   2.734 s
# Step :  137419 | Reward :  545 | Duration :   3.544 s
# Step :  137748 | Reward :  650 | Duration :   4.073 s
# Step :  137985 | Reward :  330 | Duration :   2.950 s
# Step :  138225 | Reward :  410 | Duration :   2.929 s
# Step :  138452 | Reward :  415 | Duration :   2.770 s
# Step :  138695 | Reward :  365 | Duration :   3.124 s
# Step :  138962 | Reward :  465 | Duration :   3.315 s
# Step :  139183 | Reward :  330 | Duration :   2.628 s
# Step :  139420 | Reward :  250 | Duration :   2.924 s
# Step :  139597 | Reward :   95 | Duration :   2.149 s
# Step :  139890 | Reward :  385 | Duration :   3.638 s
# Step :  140062 | Reward :  200 | Duration :   1.996 s
# Step :  140225 | Reward :  210 | Duration :   2.111 s
# Step :  140538 | Reward :  570 | Duration :   3.687 s
# Step :  140788 | Reward :  405 | Duration :   3.094 s
# Step :  141014 | Reward :  325 | Duration :   2.732 s
# Step :  141225 | Reward :  410 | Duration :   2.528 s
# Step :  141379 | Reward :  165 | Duration :   1.954 s
# Step :  141640 | Reward :  295 | Duration :   3.117 s
# Step :  141904 | Reward :  635 | Duration :   3.271 s
# Step :  142349 | Reward :  770 | Duration :   5.242 s
# Step :  142525 | Reward :  230 | Duration :   2.171 s
# Step :  142767 | Reward :  570 | Duration :   2.988 s
# Step :  142958 | Reward :  230 | Duration :   2.296 s
# Step :  143188 | Reward :  285 | Duration :   2.871 s
# Step :  143416 | Reward :  290 | Duration :   2.722 s
# Step :  143677 | Reward :  355 | Duration :   3.133 s
# Step :  143808 | Reward :  145 | Duration :   1.899 s
# Step :  144029 | Reward :  290 | Duration :   2.668 s
# Step :  144266 | Reward :  340 | Duration :   2.955 s
# Step :  144479 | Reward :  315 | Duration :   2.545 s
# Step :  144714 | Reward :  310 | Duration :   2.903 s
# Step :  144904 | Reward :  275 | Duration :   2.409 s
# Step :  145103 | Reward :  275 | Duration :   2.408 s
# Step :  145439 | Reward :  865 | Duration :   4.092 s
# Step :  145648 | Reward :  325 | Duration :   2.928 s
# Step :  145971 | Reward :  575 | Duration :   3.836 s
# Step :  146163 | Reward :  235 | Duration :   2.361 s
# Step :  146460 | Reward :  465 | Duration :   3.455 s
# Step :  146684 | Reward :  560 | Duration :   2.729 s
# Step :  146980 | Reward :  430 | Duration :   3.612 s
# Step :  147256 | Reward :  490 | Duration :   3.342 s
# Step :  147568 | Reward :  435 | Duration :   4.032 s
# Step :  147753 | Reward :  280 | Duration :   2.169 s
# Step :  147950 | Reward :  255 | Duration :   2.329 s
# Step :  148183 | Reward :  320 | Duration :   2.898 s
# Step :  148319 | Reward :  155 | Duration :   1.617 s
# Step :  148497 | Reward :  240 | Duration :   2.300 s
# Step :  148735 | Reward :  370 | Duration :   2.769 s
# Step :  149062 | Reward :  390 | Duration :   4.087 s
# Step :  149207 | Reward :  150 | Duration :   1.774 s
# Step :  149335 | Reward :  180 | Duration :   1.591 s
# Step :  149687 | Reward :  465 | Duration :   4.209 s
# Step :  149893 | Reward :  350 | Duration :   2.552 s
# Step :  150017 | Reward :  130 | Duration :   1.621 s
# Step :  150139 | Reward :  155 | Duration :   1.409 s
# Step :  150505 | Reward :  450 | Duration :   4.514 s
# Step :  150713 | Reward :  520 | Duration :   2.507 s
# Step :  150958 | Reward :  280 | Duration :   3.283 s
# Step :  151242 | Reward :  380 | Duration :   3.476 s
# Step :  151483 | Reward :  305 | Duration :   2.959 s
# Step :  151690 | Reward :  330 | Duration :   2.593 s
# Step :  151939 | Reward :  345 | Duration :   3.154 s
# Step :  152173 | Reward :  480 | Duration :   2.827 s
# Step :  152403 | Reward :  240 | Duration :   2.919 s
# Step :  152600 | Reward :  295 | Duration :   2.406 s
# Step :  152825 | Reward :  340 | Duration :   2.794 s
# Step :  153052 | Reward :  310 | Duration :   2.732 s
# Step :  153239 | Reward :  315 | Duration :   2.327 s
# Step :  153431 | Reward :  335 | Duration :   2.382 s
# Step :  153765 | Reward :  385 | Duration :   4.063 s
# Step :  153974 | Reward :  315 | Duration :   2.500 s
# Step :  154200 | Reward :  240 | Duration :   2.751 s
# Step :  154396 | Reward :  315 | Duration :   2.360 s
# Step :  154719 | Reward :  625 | Duration :   3.920 s
# Step :  154958 | Reward :  380 | Duration :   2.932 s
# Step :  155259 | Reward :  420 | Duration :   3.771 s
# Step :  155550 | Reward :  370 | Duration :   3.625 s
# Step :  155899 | Reward :  495 | Duration :   4.269 s
# Step :  156076 | Reward :  210 | Duration :   2.192 s
# Step :  156361 | Reward :  350 | Duration :   3.855 s
# Step :  156501 | Reward :  120 | Duration :   1.806 s
# Step :  156802 | Reward :  440 | Duration :   3.728 s
# Step :  157090 | Reward :  435 | Duration :   3.574 s
# Step :  157341 | Reward :  420 | Duration :   2.961 s
# Step :  157705 | Reward :  405 | Duration :   4.421 s
# Step :  158143 | Reward :  770 | Duration :   5.360 s
# Step :  158423 | Reward :  375 | Duration :   3.551 s
# Step :  158675 | Reward :  310 | Duration :   3.171 s
# Step :  158803 | Reward :  115 | Duration :   1.598 s
# Step :  159003 | Reward :  170 | Duration :   2.405 s
# Step :  159176 | Reward :  105 | Duration :   2.109 s
# Step :  159277 | Reward :    0 | Duration :   1.231 s
# Step :  159486 | Reward :  360 | Duration :   2.564 s
# Step :  159662 | Reward :  185 | Duration :   2.197 s
# Step :  159900 | Reward :  260 | Duration :   3.182 s
# Step :  160178 | Reward :  680 | Duration :   3.533 s
# Step :  160400 | Reward :  225 | Duration :   2.766 s
# Step :  160631 | Reward :  180 | Duration :   2.795 s
# Step :  160896 | Reward :  430 | Duration :   3.323 s
# Step :  161041 | Reward :  100 | Duration :   1.818 s
# Step :  161263 | Reward :  255 | Duration :   2.656 s
# Step :  161607 | Reward :  480 | Duration :   4.288 s
# Step :  161840 | Reward :  355 | Duration :   2.945 s
# Step :  162026 | Reward :  225 | Duration :   2.211 s
# Step :  162230 | Reward :  205 | Duration :   2.515 s
# Step :  162459 | Reward :  395 | Duration :   2.769 s
# Step :  162678 | Reward :  270 | Duration :   2.763 s
# Step :  162870 | Reward :  235 | Duration :   2.399 s
# Step :  163177 | Reward :  510 | Duration :   3.671 s
# Step :  163305 | Reward :  105 | Duration :   1.636 s
# Step :  163524 | Reward :  375 | Duration :   2.783 s
# Step :  164135 | Reward : 1060 | Duration :   7.379 s
# Step :  164275 | Reward :  210 | Duration :   1.804 s
# Step :  164600 | Reward :  440 | Duration :   3.978 s
# Step :  164806 | Reward :  285 | Duration :   2.578 s
# Step :  165018 | Reward :  340 | Duration :   2.590 s
# Step :  165167 | Reward :  100 | Duration :   1.778 s
# Step :  165460 | Reward :  550 | Duration :   3.696 s
# Step :  165749 | Reward :  445 | Duration :   3.531 s
# Step :  166007 | Reward :  565 | Duration :   3.230 s
# Step :  166143 | Reward :  225 | Duration :   1.589 s
# Step :  166437 | Reward :  300 | Duration :   3.753 s
# Step :  166751 | Reward :  305 | Duration :   3.813 s
# Step :  166875 | Reward :  115 | Duration :   1.554 s
# Step :  167173 | Reward :  400 | Duration :   3.882 s
# Step :  167410 | Reward :  495 | Duration :   2.958 s
# Step :  167509 | Reward :   10 | Duration :   1.219 s
# Step :  167802 | Reward :  330 | Duration :   3.544 s
# Step :  168024 | Reward :  335 | Duration :   2.711 s
# Step :  168253 | Reward :  310 | Duration :   2.835 s
# Step :  168588 | Reward :  440 | Duration :   4.159 s
# Step :  168841 | Reward :  465 | Duration :   3.440 s
# Step :  169135 | Reward :  360 | Duration :   3.581 s
# Step :  169379 | Reward :  355 | Duration :   3.109 s
# Step :  169563 | Reward :  290 | Duration :   2.213 s
# Step :  169778 | Reward :  340 | Duration :   2.705 s
# Step :  169959 | Reward :  235 | Duration :   2.165 s
# Step :  170201 | Reward :  365 | Duration :   3.002 s
# Step :  170436 | Reward :  755 | Duration :   2.986 s
# Step :  170666 | Reward :  375 | Duration :   3.005 s
# Step :  170807 | Reward :  160 | Duration :   1.774 s
# Step :  171020 | Reward :  310 | Duration :   2.572 s
# Step :  171300 | Reward :  290 | Duration :   3.511 s
# Step :  171567 | Reward :  440 | Duration :   3.202 s
# Step :  171849 | Reward :  270 | Duration :   3.572 s
# Step :  171990 | Reward :  175 | Duration :   1.771 s
# Step :  172166 | Reward :  215 | Duration :   2.180 s
# Step :  172368 | Reward :  440 | Duration :   2.846 s
# Step :  172653 | Reward :  475 | Duration :   3.360 s
# Step :  172842 | Reward :  290 | Duration :   2.349 s
# Step :  173037 | Reward :  360 | Duration :   2.389 s
# Step :  173342 | Reward :  780 | Duration :   3.686 s
# Step :  173636 | Reward :  540 | Duration :   3.652 s
# Step :  173790 | Reward :  235 | Duration :   1.810 s
# Step :  173993 | Reward :  350 | Duration :   2.528 s
# Step :  174174 | Reward :  250 | Duration :   2.433 s
# Step :  174345 | Reward :  305 | Duration :   2.203 s
# Step :  174635 | Reward :  605 | Duration :   3.524 s
# Step :  174957 | Reward :  510 | Duration :   3.915 s
# Step :  175077 | Reward :  135 | Duration :   1.574 s
# Step :  175389 | Reward :  570 | Duration :   3.659 s
# Step :  175608 | Reward :  350 | Duration :   2.739 s
# Step :  175849 | Reward :  385 | Duration :   3.263 s
# Step :  176089 | Reward :  435 | Duration :   2.896 s
# Step :  176438 | Reward :  505 | Duration :   4.256 s
# Step :  176697 | Reward :  400 | Duration :   3.209 s
# Step :  177052 | Reward :  575 | Duration :   4.400 s
# Step :  177225 | Reward :  205 | Duration :   2.161 s
# Step :  177481 | Reward :  300 | Duration :   3.102 s
# Step :  177705 | Reward :  385 | Duration :   2.758 s
# Step :  177949 | Reward :  370 | Duration :   3.015 s
# Step :  178127 | Reward :  310 | Duration :   2.196 s
# Step :  178354 | Reward :  405 | Duration :   2.921 s
# Step :  178485 | Reward :  155 | Duration :   1.559 s
# Step :  178797 | Reward :  495 | Duration :   3.706 s
# Step :  179021 | Reward :  410 | Duration :   2.742 s
# Step :  179217 | Reward :  465 | Duration :   2.478 s
# Step :  179458 | Reward :  420 | Duration :   2.955 s
# Step :  179681 | Reward :  410 | Duration :   2.714 s
# Step :  179893 | Reward :  330 | Duration :   2.588 s
# Step :  180135 | Reward :  325 | Duration :   2.956 s
# Step :  180444 | Reward :  375 | Duration :   3.650 s
# Step :  180717 | Reward :  285 | Duration :   3.300 s
# Step :  181095 | Reward :  450 | Duration :   4.572 s
# Step :  181424 | Reward :  450 | Duration :   4.334 s
# Step :  181682 | Reward :  345 | Duration :   3.110 s
# Step :  181813 | Reward :  190 | Duration :   1.708 s
# Step :  182019 | Reward :  365 | Duration :   2.651 s
# Step :  182254 | Reward :  305 | Duration :   2.755 s
# Step :  182483 | Reward :  410 | Duration :   2.854 s
# Step :  182800 | Reward :  515 | Duration :   4.411 s
# Step :  183020 | Reward :  360 | Duration :   2.829 s
# Step :  183242 | Reward :  390 | Duration :   2.712 s
# Step :  183437 | Reward :  410 | Duration :   2.337 s
# Step :  183661 | Reward :  370 | Duration :   2.693 s
# Step :  183879 | Reward :  345 | Duration :   2.677 s
# Step :  184174 | Reward :  410 | Duration :   3.661 s
# Step :  184434 | Reward :  390 | Duration :   5.469 s
# Step :  184649 | Reward :  340 | Duration :   4.228 s
# Step :  184840 | Reward :  260 | Duration :   3.675 s
# Step :  185063 | Reward :  530 | Duration :   2.722 s
# Step :  185245 | Reward :  275 | Duration :   2.132 s
# Step :  185447 | Reward :  290 | Duration :   2.527 s
# Step :  185596 | Reward :  240 | Duration :   1.797 s
# Step :  185775 | Reward :  230 | Duration :   2.178 s
# Step :  185866 | Reward :   80 | Duration :   1.150 s
# Step :  186097 | Reward :  395 | Duration :   2.884 s
# Step :  186312 | Reward :  635 | Duration :   2.550 s
# Step :  186581 | Reward :  420 | Duration :   3.588 s
# Step :  186826 | Reward :  305 | Duration :   2.943 s
# Step :  186999 | Reward :  265 | Duration :   2.121 s
# Step :  187219 | Reward :  355 | Duration :   2.731 s
# Step :  187366 | Reward :  185 | Duration :   1.815 s
# Step :  187568 | Reward :  295 | Duration :   2.497 s
# Step :  187898 | Reward :  620 | Duration :   3.863 s
# Step :  188091 | Reward :  315 | Duration :   2.336 s
# Step :  188271 | Reward :  260 | Duration :   2.458 s
# Step :  188488 | Reward :  350 | Duration :   2.671 s
# Step :  188614 | Reward :  110 | Duration :   1.591 s
# Step :  188853 | Reward :  420 | Duration :   2.923 s
# Step :  189091 | Reward :  290 | Duration :   2.953 s
# Step :  189338 | Reward :  340 | Duration :   2.973 s
# Step :  189574 | Reward :  305 | Duration :   2.941 s
# Step :  189792 | Reward :  310 | Duration :   2.739 s
# Step :  190037 | Reward :  290 | Duration :   3.220 s
# Step :  190160 | Reward :  140 | Duration :   1.535 s
# Step :  190444 | Reward :  670 | Duration :   3.344 s
# Step :  190641 | Reward :  165 | Duration :   2.546 s
# Step :  190876 | Reward :  275 | Duration :   2.859 s
# Step :  190971 | Reward :   45 | Duration :   1.173 s
# Step :  191199 | Reward :  355 | Duration :   2.741 s
# Step :  191376 | Reward :  315 | Duration :   2.290 s
# Step :  191662 | Reward :  485 | Duration :   3.365 s
# Step :  191908 | Reward :  300 | Duration :   3.211 s
# Step :  192162 | Reward :  650 | Duration :   3.135 s
# Step :  192642 | Reward : 1090 | Duration :   5.803 s
# Step :  192839 | Reward :  215 | Duration :   2.393 s
# Step :  193042 | Reward :  430 | Duration :   2.558 s
# Step :  193457 | Reward :  570 | Duration :   5.015 s
# Step :  193762 | Reward :  565 | Duration :   3.728 s
# Step :  193931 | Reward :  170 | Duration :   1.968 s
# Step :  194182 | Reward :  300 | Duration :   3.082 s
# Step :  194508 | Reward :  470 | Duration :   3.881 s
# Step :  194719 | Reward :  340 | Duration :   2.506 s
# Step :  194980 | Reward :  540 | Duration :   3.249 s
# Step :  195298 | Reward :  600 | Duration :   3.871 s
# Step :  195508 | Reward :  320 | Duration :   2.587 s
# Step :  195739 | Reward :  305 | Duration :   2.701 s
# Step :  196022 | Reward :  405 | Duration :   3.506 s
# Step :  196273 | Reward :  595 | Duration :   3.055 s
# Step :  196505 | Reward :  290 | Duration :   2.724 s
# Step :  196800 | Reward :  695 | Duration :   3.633 s
# Step :  197007 | Reward :  245 | Duration :   2.430 s
# Step :  197231 | Reward :  305 | Duration :   2.694 s
# Step :  197433 | Reward :  315 | Duration :   2.558 s
# Step :  197675 | Reward :  290 | Duration :   2.955 s
# Step :  197852 | Reward :  215 | Duration :   2.172 s
# Step :  198110 | Reward :  395 | Duration :   3.120 s
# Step :  198339 | Reward :  590 | Duration :   2.939 s
# Step :  198613 | Reward :  455 | Duration :   3.297 s
# Step :  198973 | Reward :  605 | Duration :   4.227 s
# Step :  199204 | Reward :  395 | Duration :   3.206 s
# Step :  199418 | Reward :  395 | Duration :   2.573 s
# Step :  199578 | Reward :  170 | Duration :   1.992 s
# Step :  199799 | Reward :  275 | Duration :   2.762 s
# Step :  199892 | Reward :  105 | Duration :   1.185 s
# Step :  200100 | Reward :  355 | Duration :   2.565 s
# Step :  200273 | Reward :  185 | Duration :   2.141 s
# Step :  200572 | Reward :  315 | Duration :   3.518 s
# Step :  200830 | Reward :  465 | Duration :   3.377 s
# Step :  201044 | Reward :  265 | Duration :   2.715 s
# Step :  201271 | Reward :  370 | Duration :   2.750 s
# Step :  201641 | Reward :  745 | Duration :   4.430 s
# Step :  202040 | Reward :  520 | Duration :   4.886 s
# Step :  202218 | Reward :  155 | Duration :   2.151 s
# Step :  202467 | Reward :  365 | Duration :   3.102 s
# Step :  202680 | Reward :  310 | Duration :   2.627 s
# Step :  202887 | Reward :  370 | Duration :   2.545 s
# Step :  203189 | Reward :  685 | Duration :   3.704 s
# Step :  203418 | Reward :  565 | Duration :   2.759 s
# Step :  203511 | Reward :  105 | Duration :   1.211 s
# Step :  203762 | Reward :  435 | Duration :   3.099 s
# Step :  204118 | Reward :  600 | Duration :   4.292 s
# Step :  204327 | Reward :  295 | Duration :   2.563 s
# Step :  204570 | Reward :  395 | Duration :   2.930 s
# Step :  204772 | Reward :  265 | Duration :   2.541 s
# Step :  204993 | Reward :  555 | Duration :   2.670 s
# Step :  205356 | Reward :  600 | Duration :   4.240 s
# Step :  205542 | Reward :  350 | Duration :   2.337 s
# Step :  205781 | Reward :  285 | Duration :   2.935 s
# Step :  206026 | Reward :  480 | Duration :   2.998 s
# Step :  206302 | Reward :  440 | Duration :   3.456 s
# Step :  206509 | Reward :  335 | Duration :   2.531 s
# Step :  206757 | Reward :  595 | Duration :   3.126 s
# Step :  207013 | Reward :  590 | Duration :   3.089 s
# Step :  207201 | Reward :  335 | Duration :   2.300 s
# Step :  207408 | Reward :  395 | Duration :   2.540 s
# ...
# Step :  413091 | Reward :  370 | Duration :   3.119 s
# Step :  413170 | Reward :   10 | Duration :   0.984 s
# Step :  413263 | Reward :   60 | Duration :   1.071 s
# Step :  413477 | Reward :  365 | Duration :   2.724 s
# Step :  413747 | Reward :  455 | Duration :   3.429 s
# Step :  414028 | Reward :  365 | Duration :   3.419 s
# Step :  414277 | Reward :  345 | Duration :   3.121 s
# Step :  414468 | Reward :  230 | Duration :   2.344 s
# Step :  414598 | Reward :  215 | Duration :   1.618 s
# Step :  414728 | Reward :  210 | Duration :   1.595 s
# Step :  414988 | Reward :  420 | Duration :   3.207 s
# Step :  415344 | Reward :  545 | Duration :   4.559 s
# Step :  415529 | Reward :  215 | Duration :   2.256 s
# Step :  415802 | Reward :  600 | Duration :   3.312 s
# Step :  415976 | Reward :  285 | Duration :   2.120 s
# Step :  416229 | Reward :  415 | Duration :   3.185 s
# Step :  416547 | Reward :  570 | Duration :   3.978 s
# Step :  416711 | Reward :  185 | Duration :   2.003 s
# Step :  416979 | Reward :  420 | Duration :   3.345 s
# Step :  417284 | Reward :  575 | Duration :   3.756 s
# Step :  417584 | Reward :  410 | Duration :   3.668 s
# Step :  417775 | Reward :  370 | Duration :   2.239 s
# Step :  417996 | Reward :  325 | Duration :   2.760 s
# Step :  418235 | Reward :  315 | Duration :   3.130 s
# Step :  418486 | Reward :  340 | Duration :   3.201 s
# Step :  418565 | Reward :   30 | Duration :   1.045 s
# Step :  418720 | Reward :    5 | Duration :   1.955 s
# Step :  418845 | Reward :    0 | Duration :   1.467 s
# Step :  419075 | Reward :  280 | Duration :   2.928 s
# Step :  419318 | Reward :  280 | Duration :   2.940 s
# Step :  419409 | Reward :   30 | Duration :   1.155 s
# Step :  419731 | Reward :  450 | Duration :   3.951 s
# Step :  419950 | Reward :  265 | Duration :   2.666 s
# Step :  420150 | Reward :  210 | Duration :   2.640 s
# Step :  420395 | Reward :  315 | Duration :   3.006 s
# Step :  420629 | Reward :  295 | Duration :   2.967 s
# Step :  420908 | Reward :  405 | Duration :   3.360 s
# Step :  421083 | Reward :  205 | Duration :   2.194 s
# Step :  421453 | Reward :  975 | Duration :   4.501 s
# Step :  421691 | Reward :  305 | Duration :   3.018 s
# Step :  421998 | Reward :  470 | Duration :   3.737 s
# Step :  422347 | Reward :  550 | Duration :   4.335 s
# Step :  422602 | Reward :  335 | Duration :   3.174 s
# Step :  422920 | Reward :  470 | Duration :   3.927 s
# Step :  423066 | Reward :  135 | Duration :   1.825 s
# Step :  423292 | Reward :  235 | Duration :   3.085 s
# Step :  423478 | Reward :  225 | Duration :   2.284 s
# Step :  423645 | Reward :  185 | Duration :   2.004 s
# Step :  424089 | Reward :  710 | Duration :   5.432 s
# Step :  424315 | Reward :  240 | Duration :   2.752 s
# Step :  424437 | Reward :   80 | Duration :   1.544 s
# Step :  424672 | Reward :  335 | Duration :   2.930 s
# Step :  424956 | Reward :  410 | Duration :   3.348 s
# Step :  425209 | Reward :  520 | Duration :   3.362 s
# Step :  425500 | Reward :  425 | Duration :   3.545 s
# Step :  425773 | Reward :  465 | Duration :   3.329 s
# Step :  426045 | Reward :  790 | Duration :   3.362 s
# Step :  426367 | Reward :  680 | Duration :   3.936 s
# Step :  426767 | Reward :  705 | Duration :   4.917 s
# Step :  426883 | Reward :    5 | Duration :   1.521 s
# Step :  427155 | Reward :  610 | Duration :   3.477 s
# Step :  427451 | Reward :  490 | Duration :   3.571 s
# Step :  427630 | Reward :  135 | Duration :   2.207 s
# Step :  427879 | Reward :  465 | Duration :   3.147 s
# Step :  428145 | Reward :  510 | Duration :   3.355 s
# Step :  428465 | Reward :  495 | Duration :   3.857 s
# Step :  428732 | Reward :  310 | Duration :   3.302 s
# Step :  429028 | Reward :  475 | Duration :   3.916 s
# Step :  429202 | Reward :  155 | Duration :   2.177 s
# Step :  429487 | Reward :  395 | Duration :   3.464 s
# Step :  429761 | Reward :  390 | Duration :   3.508 s
# Step :  429974 | Reward :  275 | Duration :   2.525 s
# Step :  430233 | Reward :  320 | Duration :   3.122 s
# Step :  430460 | Reward :  265 | Duration :   2.763 s
# Step :  430666 | Reward :  190 | Duration :   2.834 s
# Step :  430788 | Reward :  110 | Duration :   1.605 s
# Step :  431089 | Reward :  495 | Duration :   3.663 s
# Step :  431339 | Reward :  545 | Duration :   2.953 s
# Step :  431467 | Reward :  135 | Duration :   1.575 s
# Step :  431726 | Reward :  375 | Duration :   3.134 s
# Step :  432023 | Reward :  555 | Duration :   3.703 s
# Step :  432210 | Reward :  215 | Duration :   2.315 s
# Step :  432431 | Reward :  275 | Duration :   2.926 s
# Step :  432703 | Reward :  325 | Duration :   3.338 s
# Step :  433029 | Reward :  510 | Duration :   4.032 s
# Step :  433261 | Reward :  490 | Duration :   2.811 s
# Step :  433502 | Reward :  365 | Duration :   2.987 s
# Step :  433652 | Reward :  130 | Duration :   1.921 s
# Step :  433948 | Reward :  535 | Duration :   3.600 s
# Step :  434227 | Reward :  610 | Duration :   3.854 s
# Step :  434476 | Reward :  380 | Duration :   2.968 s
# Step :  434605 | Reward :   60 | Duration :   1.611 s
# Step :  434781 | Reward :  190 | Duration :   2.184 s
# Step :  434991 | Reward :  275 | Duration :   2.548 s
# Step :  435277 | Reward :  250 | Duration :   3.565 s
# Step :  435717 | Reward :  575 | Duration :   5.411 s
# Step :  436082 | Reward :  630 | Duration :   4.533 s
# Step :  436299 | Reward :  250 | Duration :   2.608 s
# Step :  436579 | Reward :  370 | Duration :   3.495 s
# Step :  437021 | Reward :  515 | Duration :   5.292 s
# Step :  437198 | Reward :  225 | Duration :   2.153 s
# Step :  437595 | Reward :  925 | Duration :   4.806 s
# Step :  437775 | Reward :  215 | Duration :   2.550 s
# Step :  438029 | Reward :  425 | Duration :   3.129 s
# Step :  438244 | Reward :  345 | Duration :   2.700 s
# Step :  438419 | Reward :  210 | Duration :   2.180 s
# Step :  438818 | Reward :  580 | Duration :   4.837 s
# Step :  439100 | Reward :  440 | Duration :   3.384 s
# Step :  439279 | Reward :  170 | Duration :   2.193 s
# Step :  439487 | Reward :  440 | Duration :   2.534 s
# Step :  439766 | Reward :  345 | Duration :   3.866 s
# Step :  440000 | Reward :  300 | Duration :   2.908 s
# Step :  440215 | Reward :  295 | Duration :   2.547 s
# Step :  440483 | Reward :  405 | Duration :   3.285 s
# Step :  440726 | Reward :  290 | Duration :   2.956 s
# Step :  440997 | Reward :  340 | Duration :   3.341 s
# Step :  441245 | Reward :  325 | Duration :   3.042 s
# Step :  441495 | Reward :  440 | Duration :   3.168 s
# Step :  441745 | Reward :  400 | Duration :   3.099 s
# Step :  442004 | Reward :  595 | Duration :   3.210 s
# Step :  442287 | Reward :  470 | Duration :   3.333 s
# Step :  442614 | Reward :  575 | Duration :   4.023 s
# Step :  442970 | Reward :  470 | Duration :   4.251 s
# Step :  443213 | Reward :  280 | Duration :   2.958 s
# Step :  443525 | Reward :  465 | Duration :   3.905 s
# Step :  443819 | Reward :  435 | Duration :   3.504 s
# Step :  444124 | Reward :  370 | Duration :   3.766 s
# Step :  444247 | Reward :  110 | Duration :   1.574 s
# Step :  444517 | Reward :  585 | Duration :   3.351 s
# Step :  444633 | Reward :   25 | Duration :   1.401 s
# Step :  444828 | Reward :  190 | Duration :   2.395 s
# Step :  445059 | Reward :  255 | Duration :   3.238 s
# Step :  445170 | Reward :   20 | Duration :   1.374 s
# Step :  445261 | Reward :   50 | Duration :   1.038 s
# Step :  445540 | Reward :  375 | Duration :   3.463 s
# Step :  445732 | Reward :  210 | Duration :   2.344 s
# Step :  445853 | Reward :  100 | Duration :   1.434 s
# Step :  446144 | Reward :  405 | Duration :   3.653 s
# Step :  446426 | Reward :  440 | Duration :   3.379 s
# Step :  446706 | Reward :  355 | Duration :   3.519 s
# Step :  446837 | Reward :   70 | Duration :   1.756 s
# Step :  446958 | Reward :  115 | Duration :   1.409 s
# Step :  447156 | Reward :  190 | Duration :   2.584 s
# Step :  447290 | Reward :  125 | Duration :   1.659 s
# Step :  447517 | Reward :  410 | Duration :   2.798 s
# Step :  447777 | Reward :  345 | Duration :   3.330 s
# Step :  448038 | Reward :  325 | Duration :   3.170 s
# Step :  448249 | Reward :  295 | Duration :   2.529 s
# Step :  448549 | Reward :  775 | Duration :   3.988 s
# Step :  448800 | Reward :  555 | Duration :   3.125 s
# Step :  449004 | Reward :  245 | Duration :   2.409 s
# Step :  449275 | Reward :  440 | Duration :   3.322 s
# Step :  449628 | Reward :  520 | Duration :   4.317 s
# Step :  449860 | Reward :  260 | Duration :   2.943 s
# Step :  450027 | Reward :  180 | Duration :   2.051 s
# Step :  450162 | Reward :   95 | Duration :   1.725 s
# Step :  450333 | Reward :  220 | Duration :   2.362 s
# Step :  450606 | Reward :  685 | Duration :   3.319 s
# Step :  450715 | Reward :   20 | Duration :   1.363 s
# Step :  450912 | Reward :  395 | Duration :   2.510 s
# Step :  451347 | Reward :  520 | Duration :   5.124 s
# Step :  451573 | Reward :  345 | Duration :   2.731 s
# Step :  451772 | Reward :  200 | Duration :   2.393 s
# Step :  452135 | Reward :  575 | Duration :   4.681 s
# Step :  452329 | Reward :  200 | Duration :   2.388 s
# Step :  452561 | Reward :  320 | Duration :   2.915 s
# Step :  452789 | Reward :  450 | Duration :   2.810 s
# Step :  453061 | Reward :  350 | Duration :   3.312 s
# Step :  453246 | Reward :  195 | Duration :   2.168 s
# Step :  453605 | Reward :  600 | Duration :   4.427 s
# Step :  453725 | Reward :   20 | Duration :   1.406 s
# Step :  453877 | Reward :  135 | Duration :   2.249 s
# Step :  454094 | Reward :  345 | Duration :   2.604 s
# Step :  454367 | Reward :  350 | Duration :   3.348 s
# Step :  454476 | Reward :    0 | Duration :   1.377 s
# Step :  454738 | Reward :  415 | Duration :   3.354 s
# Step :  454840 | Reward :   70 | Duration :   1.262 s
# Step :  454945 | Reward :   20 | Duration :   1.348 s
# Step :  455071 | Reward :   50 | Duration :   1.477 s
# Step :  455269 | Reward :  220 | Duration :   2.571 s
# Step :  455493 | Reward :  255 | Duration :   2.735 s
# Step :  455769 | Reward :  415 | Duration :   3.505 s
# Step :  456068 | Reward :  375 | Duration :   3.666 s
# Step :  456317 | Reward :  405 | Duration :   2.939 s
# Step :  456439 | Reward :    0 | Duration :   1.555 s
# Step :  456563 | Reward :   55 | Duration :   1.623 s
# Step :  456760 | Reward :  195 | Duration :   2.385 s
# Step :  457018 | Reward :  405 | Duration :   3.117 s
# Step :  457273 | Reward :  405 | Duration :   3.376 s
# Step :  457662 | Reward :  970 | Duration :   4.584 s
# Step :  457877 | Reward :  295 | Duration :   2.727 s
# Step :  458127 | Reward :  315 | Duration :   2.998 s
# Step :  458375 | Reward :  415 | Duration :   3.120 s
# Step :  458521 | Reward :  120 | Duration :   1.888 s
# Step :  458809 | Reward :  525 | Duration :   3.488 s
# Step :  459149 | Reward :  580 | Duration :   4.046 s
# Step :  459319 | Reward :  210 | Duration :   2.187 s
# Step :  459691 | Reward :  570 | Duration :   4.419 s
# Step :  459848 | Reward :  125 | Duration :   2.024 s
# Step :  460103 | Reward :  365 | Duration :   3.175 s
# Step :  460322 | Reward :  270 | Duration :   2.762 s
# Step :  460596 | Reward :  280 | Duration :   3.350 s
# Step :  460721 | Reward :   95 | Duration :   1.550 s
# Step :  460996 | Reward :  345 | Duration :   3.352 s
# Step :  461226 | Reward :  410 | Duration :   2.778 s
# Step :  461625 | Reward :  710 | Duration :   4.839 s
# Step :  461836 | Reward :  365 | Duration :   2.570 s
# Step :  462327 | Reward :  965 | Duration :   5.946 s
# Step :  462502 | Reward :  145 | Duration :   2.170 s
# Step :  462767 | Reward :  470 | Duration :   3.367 s
# Step :  463118 | Reward :  510 | Duration :   4.314 s
# Step :  463391 | Reward :  475 | Duration :   3.361 s
# Step :  463670 | Reward :  435 | Duration :   3.442 s
# Step :  463869 | Reward :  265 | Duration :   2.381 s
# Step :  464233 | Reward :  580 | Duration :   4.401 s
# Step :  464479 | Reward :  285 | Duration :   2.984 s
# Step :  464722 | Reward :  290 | Duration :   3.303 s
# Step :  464853 | Reward :    0 | Duration :   1.604 s
# Step :  465087 | Reward :  365 | Duration :   2.787 s
# Step :  465342 | Reward :  390 | Duration :   3.111 s
# Step :  465471 | Reward :   20 | Duration :   1.554 s
# Step :  465704 | Reward :  245 | Duration :   2.951 s
# Step :  466003 | Reward :  480 | Duration :   3.822 s
# Step :  466129 | Reward :   55 | Duration :   1.582 s
# Step :  466282 | Reward :   70 | Duration :   2.171 s
# Step :  466539 | Reward :  420 | Duration :   3.121 s
# Step :  466666 | Reward :   35 | Duration :   1.562 s
# Step :  466862 | Reward :  170 | Duration :   2.410 s
# Step :  467129 | Reward :  330 | Duration :   3.315 s
# Step :  467277 | Reward :  120 | Duration :   1.819 s
# Step :  467545 | Reward :  260 | Duration :   3.352 s
# Step :  467859 | Reward :  260 | Duration :   3.874 s
# Step :  467984 | Reward :   65 | Duration :   1.534 s
# Step :  468231 | Reward :  355 | Duration :   3.177 s
# Step :  468362 | Reward :  110 | Duration :   1.597 s
# Step :  468595 | Reward :  350 | Duration :   2.906 s
# Step :  468855 | Reward :  495 | Duration :   3.112 s
# Step :  469110 | Reward :  360 | Duration :   3.137 s
# Step :  469370 | Reward :  500 | Duration :   3.122 s
# Step :  469466 | Reward :   30 | Duration :   1.184 s
# Step :  469593 | Reward :  115 | Duration :   1.613 s
# Step :  469856 | Reward :  285 | Duration :   3.448 s
# Step :  470021 | Reward :  200 | Duration :   2.007 s
# Step :  470290 | Reward :  555 | Duration :   3.312 s
# Step :  470467 | Reward :  135 | Duration :   2.141 s
# Step :  470714 | Reward :  240 | Duration :   2.959 s
# Step :  470907 | Reward :  235 | Duration :   2.371 s
# Step :  471150 | Reward :  535 | Duration :   2.971 s
# Step :  471321 | Reward :  130 | Duration :   2.195 s
# Step :  471530 | Reward :  305 | Duration :   2.882 s
# Step :  471811 | Reward :  275 | Duration :   3.481 s
# Step :  471992 | Reward :  110 | Duration :   2.142 s
# Step :  472154 | Reward :   20 | Duration :   2.001 s
# Step :  472284 | Reward :   35 | Duration :   1.616 s
# Step :  472580 | Reward :  370 | Duration :   3.712 s
# Step :  472835 | Reward :  250 | Duration :   3.090 s
# Step :  472958 | Reward :   55 | Duration :   1.422 s
# Step :  473347 | Reward :  480 | Duration :   5.111 s
# Step :  473690 | Reward :  895 | Duration :   4.147 s
# Step :  474026 | Reward :  585 | Duration :   4.179 s
# Step :  474310 | Reward :  320 | Duration :   3.549 s
# Step :  474603 | Reward :  260 | Duration :   3.531 s
# Step :  474826 | Reward :  270 | Duration :   2.751 s
# Step :  474972 | Reward :   10 | Duration :   1.774 s
# Step :  475250 | Reward :  595 | Duration :   3.734 s
# Step :  475513 | Reward :  605 | Duration :   3.179 s
# Step :  475741 | Reward :  330 | Duration :   2.718 s
# Step :  475948 | Reward :  525 | Duration :   2.571 s
# Step :  476126 | Reward :  110 | Duration :   2.199 s
# Step :  476302 | Reward :  350 | Duration :   2.152 s
# Step :  476565 | Reward :  725 | Duration :   3.274 s
# Step :  476834 | Reward :  410 | Duration :   3.323 s
# Step :  477210 | Reward :  520 | Duration :   5.060 s
# Step :  477473 | Reward :  275 | Duration :   3.448 s
# Step :  477605 | Reward :   65 | Duration :   1.615 s
# Step :  477721 | Reward :   70 | Duration :   1.378 s
# Step :  478013 | Reward :  310 | Duration :   3.539 s
# Step :  478136 | Reward :   85 | Duration :   1.552 s
# Step :  478388 | Reward :  560 | Duration :   3.098 s
# Step :  478593 | Reward :  290 | Duration :   2.556 s
# Step :  478798 | Reward :  395 | Duration :   2.698 s
# Step :  479063 | Reward :  485 | Duration :   3.371 s
# Step :  479171 | Reward :   65 | Duration :   1.496 s
# Step :  479425 | Reward :  845 | Duration :   3.296 s
# Step :  479545 | Reward :  115 | Duration :   1.484 s
# Step :  479736 | Reward :  290 | Duration :   2.380 s
# Step :  479855 | Reward :  170 | Duration :   1.456 s
# Step :  480073 | Reward :  255 | Duration :   2.886 s
# Step :  480279 | Reward :  755 | Duration :   3.654 s
# Step :  480646 | Reward :  925 | Duration :   4.911 s
# Step :  480844 | Reward :  385 | Duration :   2.381 s
# Step :  480943 | Reward :  110 | Duration :   1.185 s
# Step :  481121 | Reward :  140 | Duration :   2.423 s
# Step :  481370 | Reward :  465 | Duration :   2.995 s
# Step :  481635 | Reward :  645 | Duration :   3.340 s
# Step :  481789 | Reward :  260 | Duration :   1.867 s
